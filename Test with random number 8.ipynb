# %%
import torch
import random
import numpy as np
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from main import focal_loss,plot_training_metrics,label_smoothing_loss,train,super_class_mapping,class_to_superclass
import matplotlib.pyplot as plt

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# Check the number of available GPUs
num_gpus = torch.cuda.device_count()
print(f"Available GPUs: {num_gpus}")

# Print PyTorch and torchvision versions
print("PyTorch version:", torch.__version__)
print("torchvision version:", torchvision.__version__)
# Out:
# 使用设备: cuda
# Available GPUs: 1
# PyTorch version: 2.1.2+cu121
# torchvision version: 0.16.2+cu121

# %%
# Set the random seed
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Ensure that DataLoader workers use the same random seed
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# Set the random seed to ensure reproducibility
set_seed(8)

# %%
# Training set image preprocessing
train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),  # Randomly crop to 32x32 with 4 pixels of padding around the edges
    transforms.RandomHorizontalFlip(),     # Random horizontal flip
    transforms.ToTensor(),                 # Convert to tensor
    transforms.Normalize(
        mean=[0.5071, 0.4867, 0.4408],  # Mean of CIFAR-100
        std=[0.2675, 0.2565, 0.2761]    # Standard deviation of CIFAR-100
    )
])

# Test set image preprocessing (only normalization)
test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to tensor
    transforms.Normalize(
        mean=[0.5071, 0.4867, 0.4408],  # Mean of CIFAR-100
        std=[0.2675, 0.2565, 0.2761]    # Standard deviation of CIFAR-100
    )
])

# %%
root_path = 'data'

# Load the CIFAR-100 training dataset
trainset = torchvision.datasets.CIFAR100(root=root_path, train=True, download=True, transform=train_transform)

# Create a DataLoader for the training dataset, with worker_init_fn to ensure reproducibility
trainloader = torch.utils.data.DataLoader(
    trainset, 
    batch_size=128, 
    shuffle=True, 
    num_workers=2, 
    worker_init_fn=seed_worker  # Ensure reproducibility of the random seed for each worker
)

# Load the CIFAR-100 test dataset
testset = torchvision.datasets.CIFAR100(root=root_path, train=False, download=True, transform=test_transform)

# Create a DataLoader for the test dataset, also with worker_init_fn
testloader = torch.utils.data.DataLoader(
    testset, 
    batch_size=128, 
    shuffle=False, 
    num_workers=2, 
    worker_init_fn=seed_worker  # Ensure reproducibility of the random seed for each worker
)

)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Print the size of the training and test datasets
print(f"Training dataset size: {len(trainset)}")
print(f"Test dataset size: {len(testset)}")
# Out:
# 训练数据集的大小: 50000
# 测试数据集的大小: 10000

# %%
from Wide_ResNet import WideResNet

resnet = WideResNet(depth=28, widen_factor=10, num_classes=100)
resnet.to('cuda')
# Out:
# WideResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): WideBlock(
#       (conv1): Conv2d(16, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential(
#         (0): Conv2d(16, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): WideBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (2): WideBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (3): WideBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): WideBlock(
#       (conv1): Conv2d(160, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential(
#         (0): Conv2d(160, 320, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): WideBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (2): WideBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (3): WideBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): WideBlock(
#       (conv1): Conv2d(320, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential(
#         (0): Conv2d(320, 640, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): WideBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (2): WideBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (3): WideBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#   )
#   (avg_pool): AdaptiveAvgPool2d(output_size=1)
#   (fc): Linear(in_features=640, out_features=100, bias=True)
# )

# %%
def train(model, trainloader, testloader, criterion, optimizer, scheduler, super_class_mapping, class_to_superclass, device='cpu', num_epochs=100):
    """
    Train the model and calculate and print Top-1 accuracy, Top-5 accuracy, and Super-Class accuracy.
    Outputs the best metrics observed during training.
    """
    train_losses = []
    test_losses = []
    train_accuracies = []
    test_accuracies = []

    start_time = time.time()

    best_test_accuracy = 0.0
    best_epoch_metrics = {}

    # 用于保存上一轮学习率
    previous_lr = None

    for epoch in range(num_epochs):
        running_loss = 0.0
        correct_train = 0
        total_train = 0
        correct_super_class_train = 0
        total_super_class_train = 0

        # Training phase
        model.train()
        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

            # Calculate super-class accuracy (optional)
            for idx, label in enumerate(labels):
                superclass = class_to_superclass[label.item()]
                total_super_class_train += 1
                if predicted[idx].item() in super_class_mapping[superclass]:
                    correct_super_class_train += 1

        train_loss = running_loss / len(trainloader)
        train_accuracy = 100 * correct_train / total_train
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)

        # Validation phase
        model.eval()
        running_test_loss = 0.0
        correct_test = 0
        total_test = 0
        correct_top5 = 0
        correct_super_class_test = 0
        total_super_class_test = 0

        with torch.no_grad():
            for data in testloader:
                images, labels = data
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                running_test_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                total_test += labels.size(0)
                correct_test += (predicted == labels).sum().item()

                _, top5_preds = outputs.topk(5, dim=1)
                correct_top5 += (top5_preds == labels.view(-1, 1)).sum().item()

                # Calculate super-class accuracy (optional)
                for idx, label in enumerate(labels):
                    superclass = class_to_superclass[label.item()]
                    total_super_class_test += 1
                    if predicted[idx].item() in super_class_mapping[superclass]:
                        correct_super_class_test += 1

        test_loss = running_test_loss / len(testloader)
        test_accuracy = 100 * correct_test / total_test
        top5_accuracy = 100 * correct_top5 / total_test
        super_class_accuracy_test = 100 * correct_super_class_test / total_super_class_test
        test_losses.append(test_loss)
        test_accuracies.append(test_accuracy)

        # Print metrics
        print(f'Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.3f}, Train Acc: {train_accuracy:.2f}%, Test Loss: {test_loss:.3f}, '
              f'Test Acc: {test_accuracy:.2f}%, Top-5 Acc: {top5_accuracy:.2f}%, Super-Class Acc: {super_class_accuracy_test:.2f}%')

        # Update learning rate
        scheduler.step()
        current_lr = optimizer.param_groups[0]['lr']

        # 如果学习率发生变化，则打印新的学习率
        if previous_lr is None or current_lr != previous_lr:
            print(f'Learning Rate changed to: {current_lr:.6f}')

        # 更新 previous_lr
        previous_lr = current_lr

        # Store best accuracy and corresponding metrics
        if test_accuracy > best_test_accuracy:
            best_test_accuracy = test_accuracy
            best_epoch_metrics = {
                'epoch': epoch + 1,
                'train_loss': train_loss,
                'train_accuracy': train_accuracy,
                'test_loss': test_loss,
                'test_accuracy': test_accuracy,
                'top5_accuracy': top5_accuracy,
                'super_class_accuracy': super_class_accuracy_test
            }

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f'Finished Training in {int(minutes)}m {int(seconds)}s')

    # Output best results
    print('Best Test Results:')
    print(f'Epoch {best_epoch_metrics["epoch"]}, Train Loss: {best_epoch_metrics["train_loss"]:.3f}, Train Acc: {best_epoch_metrics["train_accuracy"]:.2f}%, '
          f'Test Loss: {best_epoch_metrics["test_loss"]:.3f}, Test Acc: {best_epoch_metrics["test_accuracy"]:.2f}%, '
          f'Top-5 Acc: {best_epoch_metrics["top5_accuracy"]:.2f}%, Super-Class Acc: {best_epoch_metrics["super_class_accuracy"]:.2f}%')

    return best_epoch_metrics, train_losses, test_losses, train_accuracies, test_accuracies

# %%
from torch.optim.lr_scheduler import MultiStepLR
import time

optimizer = optim.SGD(
    resnet.parameters(),
    lr=0.1,              # Initial learning rate (typically the maximum learning rate)
    momentum=0.9,
    weight_decay=0.0005,
    nesterov=True
)

# Instantiate the cross-entropy loss function
criterion = nn.CrossEntropyLoss()

scheduler = MultiStepLR(optimizer, milestones=[58, 64, 67, 74], gamma=0.2)

# Call the training function
e, train_losses, test_losses, train_accuracies, test_accuracies = train(
    resnet,
    trainloader,
    testloader,
    criterion,            # Use cross-entropy loss
    optimizer,
    scheduler,            # Add scheduler parameter
    super_class_mapping,  # Add super_class_mapping
    class_to_superclass,  # Add class_to_superclass
    device='cuda',
    num_epochs=80,        
)
# Out:
# Epoch 1/80, Train Loss: 4.790, Train Acc: 2.03%, Test Loss: 4.332, Test Acc: 3.80%, Top-5 Acc: 14.52%, Super-Class Acc: 11.39%
# Learning Rate changed to: 0.100000
# Epoch 2/80, Train Loss: 4.076, Train Acc: 6.33%, Test Loss: 3.842, Test Acc: 9.47%, Top-5 Acc: 30.42%, Super-Class Acc: 21.42%
# Epoch 3/80, Train Loss: 3.690, Train Acc: 11.94%, Test Loss: 3.467, Test Acc: 15.41%, Top-5 Acc: 43.71%, Super-Class Acc: 29.46%
# Epoch 4/80, Train Loss: 3.323, Train Acc: 18.54%, Test Loss: 3.173, Test Acc: 22.35%, Top-5 Acc: 51.19%, Super-Class Acc: 36.05%
# Epoch 5/80, Train Loss: 2.990, Train Acc: 25.20%, Test Loss: 2.933, Test Acc: 27.29%, Top-5 Acc: 58.04%, Super-Class Acc: 42.27%
# Epoch 6/80, Train Loss: 2.656, Train Acc: 31.65%, Test Loss: 2.690, Test Acc: 32.43%, Top-5 Acc: 64.11%, Super-Class Acc: 47.95%
# Epoch 7/80, Train Loss: 2.330, Train Acc: 38.57%, Test Loss: 2.346, Test Acc: 39.67%, Top-5 Acc: 72.18%, Super-Class Acc: 53.54%
# Epoch 8/80, Train Loss: 2.071, Train Acc: 44.13%, Test Loss: 2.325, Test Acc: 41.45%, Top-5 Acc: 73.86%, Super-Class Acc: 54.54%
# Epoch 9/80, Train Loss: 1.878, Train Acc: 48.53%, Test Loss: 2.079, Test Acc: 46.31%, Top-5 Acc: 78.22%, Super-Class Acc: 61.04%
# Epoch 10/80, Train Loss: 1.726, Train Acc: 52.24%, Test Loss: 1.784, Test Acc: 51.67%, Top-5 Acc: 81.91%, Super-Class Acc: 65.05%
# Epoch 11/80, Train Loss: 1.628, Train Acc: 54.53%, Test Loss: 2.138, Test Acc: 47.24%, Top-5 Acc: 77.11%, Super-Class Acc: 60.59%
# Epoch 12/80, Train Loss: 1.545, Train Acc: 56.47%, Test Loss: 1.749, Test Acc: 53.17%, Top-5 Acc: 82.30%, Super-Class Acc: 67.29%
# Epoch 13/80, Train Loss: 1.477, Train Acc: 58.11%, Test Loss: 1.794, Test Acc: 53.10%, Top-5 Acc: 83.43%, Super-Class Acc: 66.28%
# Epoch 14/80, Train Loss: 1.426, Train Acc: 59.58%, Test Loss: 1.729, Test Acc: 54.93%, Top-5 Acc: 83.56%, Super-Class Acc: 67.90%
# Epoch 15/80, Train Loss: 1.374, Train Acc: 60.69%, Test Loss: 1.756, Test Acc: 53.99%, Top-5 Acc: 83.04%, Super-Class Acc: 66.92%
# Epoch 16/80, Train Loss: 1.339, Train Acc: 61.80%, Test Loss: 1.523, Test Acc: 57.95%, Top-5 Acc: 86.46%, Super-Class Acc: 71.27%
# Epoch 17/80, Train Loss: 1.304, Train Acc: 62.54%, Test Loss: 1.694, Test Acc: 56.75%, Top-5 Acc: 83.94%, Super-Class Acc: 69.00%
# Epoch 18/80, Train Loss: 1.274, Train Acc: 63.48%, Test Loss: 1.553, Test Acc: 58.17%, Top-5 Acc: 86.01%, Super-Class Acc: 71.17%
# Epoch 19/80, Train Loss: 1.250, Train Acc: 63.93%, Test Loss: 1.939, Test Acc: 52.81%, Top-5 Acc: 82.43%, Super-Class Acc: 65.01%
# Epoch 20/80, Train Loss: 1.225, Train Acc: 64.71%, Test Loss: 1.658, Test Acc: 56.57%, Top-5 Acc: 85.04%, Super-Class Acc: 69.53%
# Epoch 21/80, Train Loss: 1.201, Train Acc: 65.18%, Test Loss: 1.694, Test Acc: 56.09%, Top-5 Acc: 84.08%, Super-Class Acc: 68.44%
# Epoch 22/80, Train Loss: 1.181, Train Acc: 65.92%, Test Loss: 1.732, Test Acc: 55.70%, Top-5 Acc: 84.24%, Super-Class Acc: 67.92%
# Epoch 23/80, Train Loss: 1.163, Train Acc: 66.46%, Test Loss: 1.841, Test Acc: 53.84%, Top-5 Acc: 81.56%, Super-Class Acc: 66.19%
# Epoch 24/80, Train Loss: 1.154, Train Acc: 66.42%, Test Loss: 1.666, Test Acc: 57.52%, Top-5 Acc: 85.79%, Super-Class Acc: 70.98%
# Epoch 25/80, Train Loss: 1.145, Train Acc: 66.72%, Test Loss: 1.458, Test Acc: 60.95%, Top-5 Acc: 86.78%, Super-Class Acc: 73.15%
# Epoch 26/80, Train Loss: 1.126, Train Acc: 67.28%, Test Loss: 1.651, Test Acc: 57.62%, Top-5 Acc: 85.71%, Super-Class Acc: 70.29%
# Epoch 27/80, Train Loss: 1.114, Train Acc: 67.64%, Test Loss: 1.622, Test Acc: 57.29%, Top-5 Acc: 85.27%, Super-Class Acc: 69.84%
# Epoch 28/80, Train Loss: 1.109, Train Acc: 67.63%, Test Loss: 1.653, Test Acc: 57.76%, Top-5 Acc: 85.39%, Super-Class Acc: 71.21%
# Epoch 29/80, Train Loss: 1.093, Train Acc: 68.24%, Test Loss: 1.551, Test Acc: 59.16%, Top-5 Acc: 86.57%, Super-Class Acc: 71.12%
# Epoch 30/80, Train Loss: 1.087, Train Acc: 68.31%, Test Loss: 1.517, Test Acc: 59.78%, Top-5 Acc: 86.46%, Super-Class Acc: 72.29%
# Epoch 31/80, Train Loss: 1.079, Train Acc: 68.43%, Test Loss: 1.568, Test Acc: 58.43%, Top-5 Acc: 85.89%, Super-Class Acc: 69.79%
# Epoch 32/80, Train Loss: 1.079, Train Acc: 68.56%, Test Loss: 1.454, Test Acc: 61.79%, Top-5 Acc: 88.18%, Super-Class Acc: 74.85%
# Epoch 33/80, Train Loss: 1.065, Train Acc: 69.03%, Test Loss: 1.528, Test Acc: 59.90%, Top-5 Acc: 87.15%, Super-Class Acc: 72.18%
# Epoch 34/80, Train Loss: 1.066, Train Acc: 68.86%, Test Loss: 1.461, Test Acc: 61.22%, Top-5 Acc: 87.51%, Super-Class Acc: 72.92%
# Epoch 35/80, Train Loss: 1.053, Train Acc: 69.26%, Test Loss: 1.410, Test Acc: 61.58%, Top-5 Acc: 88.14%, Super-Class Acc: 73.72%
# Epoch 36/80, Train Loss: 1.045, Train Acc: 69.35%, Test Loss: 1.435, Test Acc: 62.23%, Top-5 Acc: 88.08%, Super-Class Acc: 74.49%
# Epoch 37/80, Train Loss: 1.035, Train Acc: 69.91%, Test Loss: 1.465, Test Acc: 60.49%, Top-5 Acc: 87.20%, Super-Class Acc: 73.29%
# Epoch 38/80, Train Loss: 1.037, Train Acc: 69.65%, Test Loss: 1.391, Test Acc: 62.10%, Top-5 Acc: 88.59%, Super-Class Acc: 74.87%
# Epoch 39/80, Train Loss: 1.031, Train Acc: 69.94%, Test Loss: 1.463, Test Acc: 61.81%, Top-5 Acc: 87.10%, Super-Class Acc: 72.99%
# Epoch 40/80, Train Loss: 1.026, Train Acc: 70.09%, Test Loss: 1.433, Test Acc: 62.31%, Top-5 Acc: 88.43%, Super-Class Acc: 74.33%
# Epoch 41/80, Train Loss: 1.016, Train Acc: 70.37%, Test Loss: 1.368, Test Acc: 63.15%, Top-5 Acc: 87.77%, Super-Class Acc: 75.37%
# Epoch 42/80, Train Loss: 1.011, Train Acc: 70.41%, Test Loss: 1.509, Test Acc: 60.63%, Top-5 Acc: 87.58%, Super-Class Acc: 72.08%
# Epoch 43/80, Train Loss: 1.018, Train Acc: 70.30%, Test Loss: 1.490, Test Acc: 59.83%, Top-5 Acc: 87.14%, Super-Class Acc: 72.31%
# Epoch 44/80, Train Loss: 1.007, Train Acc: 70.64%, Test Loss: 1.485, Test Acc: 60.28%, Top-5 Acc: 86.77%, Super-Class Acc: 72.93%
# Epoch 45/80, Train Loss: 1.005, Train Acc: 70.48%, Test Loss: 1.508, Test Acc: 61.71%, Top-5 Acc: 87.38%, Super-Class Acc: 73.44%
# Epoch 46/80, Train Loss: 1.006, Train Acc: 70.89%, Test Loss: 1.379, Test Acc: 63.16%, Top-5 Acc: 88.47%, Super-Class Acc: 74.67%
# Epoch 47/80, Train Loss: 0.997, Train Acc: 70.86%, Test Loss: 1.428, Test Acc: 61.50%, Top-5 Acc: 87.01%, Super-Class Acc: 73.04%
# Epoch 48/80, Train Loss: 0.990, Train Acc: 71.09%, Test Loss: 1.507, Test Acc: 60.88%, Top-5 Acc: 87.43%, Super-Class Acc: 72.34%
# Epoch 49/80, Train Loss: 1.005, Train Acc: 70.26%, Test Loss: 1.892, Test Acc: 54.73%, Top-5 Acc: 82.91%, Super-Class Acc: 66.57%
# Epoch 50/80, Train Loss: 1.000, Train Acc: 70.76%, Test Loss: 1.594, Test Acc: 59.18%, Top-5 Acc: 86.12%, Super-Class Acc: 71.00%
# Epoch 51/80, Train Loss: 0.995, Train Acc: 70.72%, Test Loss: 1.335, Test Acc: 63.32%, Top-5 Acc: 88.84%, Super-Class Acc: 75.13%
# Epoch 52/80, Train Loss: 0.986, Train Acc: 71.04%, Test Loss: 1.547, Test Acc: 59.96%, Top-5 Acc: 86.06%, Super-Class Acc: 70.82%
# Epoch 53/80, Train Loss: 0.982, Train Acc: 71.29%, Test Loss: 1.316, Test Acc: 64.09%, Top-5 Acc: 89.53%, Super-Class Acc: 76.59%
# Epoch 54/80, Train Loss: 0.979, Train Acc: 71.59%, Test Loss: 1.503, Test Acc: 61.54%, Top-5 Acc: 87.43%, Super-Class Acc: 72.89%
# Epoch 55/80, Train Loss: 0.982, Train Acc: 71.25%, Test Loss: 1.502, Test Acc: 61.46%, Top-5 Acc: 87.20%, Super-Class Acc: 73.74%
# Epoch 56/80, Train Loss: 0.980, Train Acc: 71.24%, Test Loss: 1.438, Test Acc: 61.67%, Top-5 Acc: 87.35%, Super-Class Acc: 73.56%
# Epoch 57/80, Train Loss: 0.974, Train Acc: 71.62%, Test Loss: 1.685, Test Acc: 57.43%, Top-5 Acc: 84.59%, Super-Class Acc: 68.05%
# Epoch 58/80, Train Loss: 0.968, Train Acc: 71.74%, Test Loss: 1.629, Test Acc: 57.63%, Top-5 Acc: 85.59%, Super-Class Acc: 70.39%
# Learning Rate changed to: 0.020000
# Epoch 59/80, Train Loss: 0.567, Train Acc: 83.27%, Test Loss: 0.845, Test Acc: 76.37%, Top-5 Acc: 94.38%, Super-Class Acc: 85.29%
# Epoch 60/80, Train Loss: 0.433, Train Acc: 87.28%, Test Loss: 0.839, Test Acc: 76.54%, Top-5 Acc: 94.53%, Super-Class Acc: 85.32%
# Epoch 61/80, Train Loss: 0.373, Train Acc: 89.06%, Test Loss: 0.830, Test Acc: 77.08%, Top-5 Acc: 94.68%, Super-Class Acc: 85.88%
# Epoch 62/80, Train Loss: 0.333, Train Acc: 90.23%, Test Loss: 0.844, Test Acc: 76.79%, Top-5 Acc: 94.54%, Super-Class Acc: 85.65%
# Epoch 63/80, Train Loss: 0.303, Train Acc: 91.14%, Test Loss: 0.870, Test Acc: 76.35%, Top-5 Acc: 94.32%, Super-Class Acc: 84.99%
# Epoch 64/80, Train Loss: 0.277, Train Acc: 91.96%, Test Loss: 0.880, Test Acc: 76.82%, Top-5 Acc: 94.17%, Super-Class Acc: 85.24%
# Learning Rate changed to: 0.004000
# Epoch 65/80, Train Loss: 0.188, Train Acc: 95.05%, Test Loss: 0.786, Test Acc: 78.94%, Top-5 Acc: 95.29%, Super-Class Acc: 86.85%
# Epoch 66/80, Train Loss: 0.160, Train Acc: 95.99%, Test Loss: 0.785, Test Acc: 79.15%, Top-5 Acc: 95.34%, Super-Class Acc: 87.04%
# Epoch 67/80, Train Loss: 0.144, Train Acc: 96.54%, Test Loss: 0.792, Test Acc: 79.00%, Top-5 Acc: 95.24%, Super-Class Acc: 86.97%
# Learning Rate changed to: 0.000800
# Epoch 68/80, Train Loss: 0.130, Train Acc: 97.05%, Test Loss: 0.777, Test Acc: 79.09%, Top-5 Acc: 95.36%, Super-Class Acc: 87.01%
# Epoch 69/80, Train Loss: 0.125, Train Acc: 97.21%, Test Loss: 0.782, Test Acc: 79.11%, Top-5 Acc: 95.31%, Super-Class Acc: 87.01%
# Epoch 70/80, Train Loss: 0.122, Train Acc: 97.31%, Test Loss: 0.787, Test Acc: 78.96%, Top-5 Acc: 95.32%, Super-Class Acc: 87.00%
# Epoch 71/80, Train Loss: 0.122, Train Acc: 97.24%, Test Loss: 0.782, Test Acc: 79.22%, Top-5 Acc: 95.26%, Super-Class Acc: 87.25%
# Epoch 72/80, Train Loss: 0.117, Train Acc: 97.43%, Test Loss: 0.784, Test Acc: 79.17%, Top-5 Acc: 95.29%, Super-Class Acc: 87.19%
# Epoch 73/80, Train Loss: 0.116, Train Acc: 97.42%, Test Loss: 0.784, Test Acc: 79.19%, Top-5 Acc: 95.30%, Super-Class Acc: 87.16%
# Epoch 74/80, Train Loss: 0.114, Train Acc: 97.55%, Test Loss: 0.786, Test Acc: 79.18%, Top-5 Acc: 95.34%, Super-Class Acc: 87.18%
# Learning Rate changed to: 0.000160
# Epoch 75/80, Train Loss: 0.112, Train Acc: 97.56%, Test Loss: 0.786, Test Acc: 79.22%, Top-5 Acc: 95.30%, Super-Class Acc: 87.16%
# Epoch 76/80, Train Loss: 0.109, Train Acc: 97.73%, Test Loss: 0.782, Test Acc: 79.21%, Top-5 Acc: 95.41%, Super-Class Acc: 87.13%
# Epoch 77/80, Train Loss: 0.111, Train Acc: 97.65%, Test Loss: 0.787, Test Acc: 79.20%, Top-5 Acc: 95.27%, Super-Class Acc: 87.11%
# Epoch 78/80, Train Loss: 0.111, Train Acc: 97.60%, Test Loss: 0.793, Test Acc: 79.18%, Top-5 Acc: 95.17%, Super-Class Acc: 87.08%
# Epoch 79/80, Train Loss: 0.109, Train Acc: 97.65%, Test Loss: 0.786, Test Acc: 79.44%, Top-5 Acc: 95.25%, Super-Class Acc: 87.28%
# Epoch 80/80, Train Loss: 0.110, Train Acc: 97.67%, Test Loss: 0.784, Test Acc: 79.27%, Top-5 Acc: 95.25%, Super-Class Acc: 87.19%
# Finished Training in 626m 20s
# Best Test Results:
# Epoch 79, Train Loss: 0.109, Train Acc: 97.65%, Test Loss: 0.786, Test Acc: 79.44%, Top-5 Acc: 95.25%, Super-Class Acc: 87.28%

# %%
plot_training_metrics(train_losses, test_losses, train_accuracies, test_accuracies)
