# %%
import torch
import random
import numpy as np
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from main import focal_loss,plot_training_metrics,label_smoothing_loss,train,super_class_mapping,class_to_superclass
import matplotlib.pyplot as plt

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("使用设备:", device)

# 查看可用的 GPU 数量
num_gpus = torch.cuda.device_count()
print(f"Available GPUs: {num_gpus}")

# 打印PyTorch和torchvision版本
print("PyTorch version:", torch.__version__)
print("torchvision version:", torchvision.__version__)
# Out:
# 使用设备: cuda
# Available GPUs: 1
# PyTorch version: 2.1.2+cu121
# torchvision version: 0.16.2+cu121

# %%
# 设置随机种子
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# 确保 DataLoader 的 worker 使用相同的随机种子
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# 设置随机种子，确保可复现性
set_seed(4)

# %%
# 训练集图像预处理
train_transform = transforms.Compose([
    #transforms.RandomResizedCrop(size=32, scale=(0.8, 1.0)),  # 随机裁剪并缩放到32x32
    transforms.RandomHorizontalFlip(p=0.5),  # 随机水平翻转
    transforms.RandomRotation(degrees=10),  # 随机旋转10度以内
    transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.1),  # 改变亮度、对比度、饱和度、色调
    transforms.RandAugment(num_ops=2, magnitude=9),  # 使用 RandAugment 自动增强
    transforms.ToTensor(),  # 转为 Tensor 格式
    transforms.Normalize(
        mean=[0.5071, 0.4867, 0.4408],  # CIFAR-100 的均值
        std=[0.2675, 0.2565, 0.2761]  # CIFAR-100 的标准差
    )
])

# 测试集图像预处理（仅标准化处理）
test_transform = transforms.Compose([
    transforms.ToTensor(),  # 转为 Tensor 格式
    transforms.Normalize(
        mean=[0.5071, 0.4867, 0.4408],  # CIFAR-100 的均值
        std=[0.2675, 0.2565, 0.2761]  # CIFAR-100 的标准差
    )
])

# %%
root_path = 'data'

# 加载CIFAR-100训练数据集
trainset = torchvision.datasets.CIFAR100(root=root_path, train=True, download=True, transform=train_transform)

# 创建训练数据集的DataLoader，添加 worker_init_fn 参数，确保可复现
trainloader = torch.utils.data.DataLoader(
    trainset, 
    batch_size=32, 
    shuffle=True, 
    num_workers=2, 
    worker_init_fn=seed_worker  # 确保每个 worker 的随机种子可复现
)

# 加载CIFAR-100测试数据集
testset = torchvision.datasets.CIFAR100(root=root_path, train=False, download=True, transform=test_transform)

# 创建测试数据集的DataLoader，同样添加 worker_init_fn 参数
testloader = torch.utils.data.DataLoader(
    testset, 
    batch_size=32, 
    shuffle=False, 
    num_workers=2, 
    worker_init_fn=seed_worker  # 确保每个 worker 的随机种子可复现
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# 打印训练集和测试集的大小
print(f"训练数据集的大小: {len(trainset)}")
print(f"测试数据集的大小: {len(testset)}")
# Out:
# 训练数据集的大小: 50000
# 测试数据集的大小: 10000

# %%
from reslp import ResNet

# 创建更深的模型实例
resnet = ResNet(num_classes=100)  # 对于 CIFAR-100, num_classes 应为 100
resnet.to('cuda')
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (layer1): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#     )
#     (1): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#     )
#     (2): ResidualBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#     )
#   )
#   (layer2): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#     )
#     (2): ResidualBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#     )
#     (3): ResidualBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#     )
#   )
#   (layer3): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#     )
#     (2): ResidualBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#     )
#     (3): ResidualBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#     )
#     (4): ResidualBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#     )
#     (5): ResidualBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#     )
#   )
#   (layer4): Sequential(
#     (0): ResidualBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): ResidualBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#     )
#     (2): ResidualBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Identity()
#     )
#   )
#   (avg_pool): AdaptiveAvgPool2d(output_size=1)
#   (fc): Linear(in_features=512, out_features=100, bias=True)
# )

# %%
def train(model, trainloader, testloader, criterion, optimizer, scheduler, super_class_mapping, class_to_superclass, device='cpu', num_epochs=100, use_early_stopping=False):
    """
    Train the model and calculate and print Top-1 accuracy, Top-5 accuracy, and Super-Class accuracy.
    Outputs the best metrics observed during training.
    """
    train_losses = []
    test_losses = []
    train_accuracies = []
    test_accuracies = []

    start_time = time.time()

    best_test_accuracy = 0.0
    best_epoch_metrics = {}

    no_improvement_count = 0

    for epoch in range(num_epochs):
        running_loss = 0.0
        correct_train = 0
        total_train = 0
        correct_super_class_train = 0
        total_super_class_train = 0

        # Training phase
        model.train()
        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

            # Calculate super-class accuracy (optional)
            for idx, label in enumerate(labels):
                superclass = class_to_superclass[label.item()]
                total_super_class_train += 1
                if predicted[idx].item() in super_class_mapping[superclass]:
                    correct_super_class_train += 1

        train_loss = running_loss / len(trainloader)
        train_accuracy = 100 * correct_train / total_train
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)

        # Validation phase
        model.eval()
        running_test_loss = 0.0
        correct_test = 0
        total_test = 0
        correct_top5 = 0
        correct_super_class_test = 0
        total_super_class_test = 0

        with torch.no_grad():
            for data in testloader:
                images, labels = data
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                running_test_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                total_test += labels.size(0)
                correct_test += (predicted == labels).sum().item()

                _, top5_preds = outputs.topk(5, dim=1)
                correct_top5 += (top5_preds == labels.view(-1, 1)).sum().item()

                # Calculate super-class accuracy (optional)
                for idx, label in enumerate(labels):
                    superclass = class_to_superclass[label.item()]
                    total_super_class_test += 1
                    if predicted[idx].item() in super_class_mapping[superclass]:
                        correct_super_class_test += 1

        test_loss = running_test_loss / len(testloader)
        test_accuracy = 100 * correct_test / total_test
        top5_accuracy = 100 * correct_top5 / total_test
        super_class_accuracy_test = 100 * correct_super_class_test / total_super_class_test
        test_losses.append(test_loss)
        test_accuracies.append(test_accuracy)

        # Print metrics
        print(f'Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.3f}, Train Acc: {train_accuracy:.2f}%, Test Loss: {test_loss:.3f}, '
              f'Test Acc: {test_accuracy:.2f}%, Top-5 Acc: {top5_accuracy:.2f}%, Super-Class Acc: {super_class_accuracy_test:.2f}%')

        # Update learning rate
        scheduler.step()
        current_lr = optimizer.param_groups[0]['lr']
        print(f'Current Learning Rate: {current_lr:.6f}')

        # Store best accuracy and corresponding metrics
        if test_accuracy > best_test_accuracy:
            best_test_accuracy = test_accuracy
            best_epoch_metrics = {
                'epoch': epoch + 1,
                'train_loss': train_loss,
                'train_accuracy': train_accuracy,
                'test_loss': test_loss,
                'test_accuracy': test_accuracy,
                'top5_accuracy': top5_accuracy,
                'super_class_accuracy': super_class_accuracy_test
            }

        # Early stopping (if required)
        if use_early_stopping:
            if test_accuracy > best_test_accuracy:
                no_improvement_count = 0
            else:
                no_improvement_count += 1

            if no_improvement_count >= patience:
                print(f'Early stopping at epoch {epoch + 1}, best accuracy: {best_test_accuracy:.2f}%')
                break

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f'Finished Training in {int(minutes)}m {int(seconds)}s')

    # Output best results
    print('Best Test Results:')
    print(f'Epoch {best_epoch_metrics["epoch"]}, Train Loss: {best_epoch_metrics["train_loss"]:.3f}, Train Acc: {best_epoch_metrics["train_accuracy"]:.2f}%, '
          f'Test Loss: {best_epoch_metrics["test_loss"]:.3f}, Test Acc: {best_epoch_metrics["test_accuracy"]:.2f}%, '
          f'Top-5 Acc: {best_epoch_metrics["top5_accuracy"]:.2f}%, Super-Class Acc: {best_epoch_metrics["super_class_accuracy"]:.2f}%')

    return best_epoch_metrics, train_losses, test_losses, train_accuracies, test_accuracies

# %%
label_smoothing_loss
# Out:
# <function main.label_smoothing_loss(pred, target, smoothing=0.175)>

# %%
from torch.optim.lr_scheduler import CosineAnnealingLR
import time

# %%
#label_smoothing_loss，smoothing=0.175，momentum=0.95，bitch_size=32，nesterov=True，ReduceLROnPlateau 调度器
optimizer = optim.SGD(
    resnet.parameters(),
    lr=0.05,              # 初始学习率（通常为最大学习率）
    momentum=0.95,
    weight_decay=0.0001,
    nesterov=True
)
num_epochs=150
steps_per_epoch = len(trainloader)
total_steps = num_epochs * steps_per_epoch

scheduler = CosineAnnealingLR(optimizer, T_max=num_epochs, eta_min=0)

# 调用训练函数
e,train_losses, test_losses, train_accuracies, test_accuracies = train(
    resnet,
    trainloader,
    testloader,
    label_smoothing_loss,  # 使用标签平滑损失，如果有定义
    optimizer,
    scheduler,             # 添加 scheduler 参数
    super_class_mapping,   # 添加 super_class_mapping
    class_to_superclass,   # 添加 class_to_superclass
    device='cuda',
    num_epochs=150,        # 设置为 100 个 epoch
    use_early_stopping=False  # 根据需要启用或禁用早停法
)
# Out:
# Epoch 1/150, Train Loss: 4.561, Train Acc: 2.58%, Test Loss: 4.295, Test Acc: 5.34%, Top-5 Acc: 21.63%, Super-Class Acc: 14.62%
# Current Learning Rate: 0.049995
# Epoch 2/150, Train Loss: 4.254, Train Acc: 7.22%, Test Loss: 3.961, Test Acc: 13.94%, Top-5 Acc: 38.80%, Super-Class Acc: 27.02%
# Current Learning Rate: 0.049978
# Epoch 3/150, Train Loss: 3.973, Train Acc: 13.97%, Test Loss: 3.626, Test Acc: 22.57%, Top-5 Acc: 52.21%, Super-Class Acc: 36.32%
# Current Learning Rate: 0.049951
# Epoch 4/150, Train Loss: 3.661, Train Acc: 22.06%, Test Loss: 3.268, Test Acc: 32.44%, Top-5 Acc: 64.00%, Super-Class Acc: 47.19%
# Current Learning Rate: 0.049912
# Epoch 5/150, Train Loss: 3.379, Train Acc: 29.77%, Test Loss: 3.015, Test Acc: 40.55%, Top-5 Acc: 71.93%, Super-Class Acc: 54.72%
# Current Learning Rate: 0.049863
# Epoch 6/150, Train Loss: 3.178, Train Acc: 35.38%, Test Loss: 2.877, Test Acc: 45.09%, Top-5 Acc: 75.87%, Super-Class Acc: 59.69%
# Current Learning Rate: 0.049803
# Epoch 7/150, Train Loss: 3.029, Train Acc: 40.11%, Test Loss: 2.732, Test Acc: 49.89%, Top-5 Acc: 79.65%, Super-Class Acc: 63.82%
# Current Learning Rate: 0.049732
# Epoch 8/150, Train Loss: 2.927, Train Acc: 43.31%, Test Loss: 2.755, Test Acc: 48.69%, Top-5 Acc: 79.11%, Super-Class Acc: 61.73%
# Current Learning Rate: 0.049650
# Epoch 9/150, Train Loss: 2.845, Train Acc: 45.77%, Test Loss: 2.626, Test Acc: 53.46%, Top-5 Acc: 82.42%, Super-Class Acc: 66.48%
# Current Learning Rate: 0.049557
# Epoch 10/150, Train Loss: 2.790, Train Acc: 47.68%, Test Loss: 2.593, Test Acc: 54.18%, Top-5 Acc: 82.58%, Super-Class Acc: 67.21%
# Current Learning Rate: 0.049454
# Epoch 11/150, Train Loss: 2.741, Train Acc: 49.17%, Test Loss: 2.554, Test Acc: 55.29%, Top-5 Acc: 83.39%, Super-Class Acc: 67.86%
# Current Learning Rate: 0.049339
# Epoch 12/150, Train Loss: 2.690, Train Acc: 50.76%, Test Loss: 2.535, Test Acc: 55.20%, Top-5 Acc: 84.01%, Super-Class Acc: 68.88%
# Current Learning Rate: 0.049215
# Epoch 13/150, Train Loss: 2.646, Train Acc: 52.22%, Test Loss: 2.466, Test Acc: 57.96%, Top-5 Acc: 85.41%, Super-Class Acc: 70.81%
# Current Learning Rate: 0.049079
# Epoch 14/150, Train Loss: 2.613, Train Acc: 53.19%, Test Loss: 2.488, Test Acc: 58.10%, Top-5 Acc: 84.91%, Super-Class Acc: 70.83%
# Current Learning Rate: 0.048933
# Epoch 15/150, Train Loss: 2.588, Train Acc: 54.18%, Test Loss: 2.433, Test Acc: 59.46%, Top-5 Acc: 86.27%, Super-Class Acc: 71.82%
# Current Learning Rate: 0.048776
# Epoch 16/150, Train Loss: 2.558, Train Acc: 55.03%, Test Loss: 2.481, Test Acc: 57.62%, Top-5 Acc: 85.47%, Super-Class Acc: 70.11%
# Current Learning Rate: 0.048609
# Epoch 17/150, Train Loss: 2.541, Train Acc: 55.63%, Test Loss: 2.367, Test Acc: 61.26%, Top-5 Acc: 87.31%, Super-Class Acc: 73.73%
# Current Learning Rate: 0.048432
# Epoch 18/150, Train Loss: 2.520, Train Acc: 56.42%, Test Loss: 2.370, Test Acc: 61.58%, Top-5 Acc: 87.24%, Super-Class Acc: 73.80%
# Current Learning Rate: 0.048244
# Epoch 19/150, Train Loss: 2.494, Train Acc: 57.11%, Test Loss: 2.457, Test Acc: 59.02%, Top-5 Acc: 85.56%, Super-Class Acc: 71.53%
# Current Learning Rate: 0.048047
# Epoch 20/150, Train Loss: 2.477, Train Acc: 57.72%, Test Loss: 2.358, Test Acc: 61.94%, Top-5 Acc: 87.19%, Super-Class Acc: 73.72%
# Current Learning Rate: 0.047839
# Epoch 21/150, Train Loss: 2.461, Train Acc: 58.38%, Test Loss: 2.394, Test Acc: 61.36%, Top-5 Acc: 87.11%, Super-Class Acc: 73.15%
# Current Learning Rate: 0.047621
# Epoch 22/150, Train Loss: 2.450, Train Acc: 58.60%, Test Loss: 2.330, Test Acc: 62.65%, Top-5 Acc: 88.12%, Super-Class Acc: 74.76%
# Current Learning Rate: 0.047393
# Epoch 23/150, Train Loss: 2.427, Train Acc: 59.54%, Test Loss: 2.326, Test Acc: 62.98%, Top-5 Acc: 87.82%, Super-Class Acc: 74.53%
# Current Learning Rate: 0.047155
# Epoch 24/150, Train Loss: 2.420, Train Acc: 59.75%, Test Loss: 2.349, Test Acc: 62.28%, Top-5 Acc: 88.13%, Super-Class Acc: 75.24%
# Current Learning Rate: 0.046908
# Epoch 25/150, Train Loss: 2.406, Train Acc: 59.99%, Test Loss: 2.335, Test Acc: 62.54%, Top-5 Acc: 88.04%, Super-Class Acc: 74.21%
# Current Learning Rate: 0.046651
# Epoch 26/150, Train Loss: 2.394, Train Acc: 60.50%, Test Loss: 2.294, Test Acc: 64.13%, Top-5 Acc: 88.44%, Super-Class Acc: 75.73%
# Current Learning Rate: 0.046384
# Epoch 27/150, Train Loss: 2.379, Train Acc: 60.98%, Test Loss: 2.333, Test Acc: 62.35%, Top-5 Acc: 87.48%, Super-Class Acc: 74.69%
# Current Learning Rate: 0.046108
# Epoch 28/150, Train Loss: 2.374, Train Acc: 61.20%, Test Loss: 2.344, Test Acc: 62.46%, Top-5 Acc: 87.42%, Super-Class Acc: 74.20%
# Current Learning Rate: 0.045823
# Epoch 29/150, Train Loss: 2.357, Train Acc: 61.84%, Test Loss: 2.301, Test Acc: 63.68%, Top-5 Acc: 88.49%, Super-Class Acc: 75.52%
# Current Learning Rate: 0.045529
# Epoch 30/150, Train Loss: 2.352, Train Acc: 61.82%, Test Loss: 2.291, Test Acc: 63.71%, Top-5 Acc: 88.67%, Super-Class Acc: 76.23%
# Current Learning Rate: 0.045225
# Epoch 31/150, Train Loss: 2.337, Train Acc: 62.56%, Test Loss: 2.298, Test Acc: 63.52%, Top-5 Acc: 88.85%, Super-Class Acc: 75.18%
# Current Learning Rate: 0.044913
# Epoch 32/150, Train Loss: 2.325, Train Acc: 62.91%, Test Loss: 2.318, Test Acc: 63.49%, Top-5 Acc: 88.10%, Super-Class Acc: 74.95%
# Current Learning Rate: 0.044592
# Epoch 33/150, Train Loss: 2.326, Train Acc: 63.08%, Test Loss: 2.316, Test Acc: 63.11%, Top-5 Acc: 88.89%, Super-Class Acc: 74.85%
# Current Learning Rate: 0.044263
# Epoch 34/150, Train Loss: 2.314, Train Acc: 63.37%, Test Loss: 2.265, Test Acc: 64.83%, Top-5 Acc: 88.59%, Super-Class Acc: 76.13%
# Current Learning Rate: 0.043925
# Epoch 35/150, Train Loss: 2.302, Train Acc: 63.85%, Test Loss: 2.301, Test Acc: 64.13%, Top-5 Acc: 88.48%, Super-Class Acc: 75.63%
# Current Learning Rate: 0.043579
# Epoch 36/150, Train Loss: 2.296, Train Acc: 63.72%, Test Loss: 2.251, Test Acc: 65.29%, Top-5 Acc: 89.17%, Super-Class Acc: 76.86%
# Current Learning Rate: 0.043224
# Epoch 37/150, Train Loss: 2.289, Train Acc: 64.15%, Test Loss: 2.261, Test Acc: 65.43%, Top-5 Acc: 89.46%, Super-Class Acc: 77.00%
# Current Learning Rate: 0.042862
# Epoch 38/150, Train Loss: 2.285, Train Acc: 64.09%, Test Loss: 2.299, Test Acc: 63.64%, Top-5 Acc: 88.40%, Super-Class Acc: 75.63%
# Current Learning Rate: 0.042492
# Epoch 39/150, Train Loss: 2.275, Train Acc: 64.68%, Test Loss: 2.286, Test Acc: 64.30%, Top-5 Acc: 88.46%, Super-Class Acc: 75.86%
# Current Learning Rate: 0.042114
# Epoch 40/150, Train Loss: 2.269, Train Acc: 64.74%, Test Loss: 2.283, Test Acc: 64.57%, Top-5 Acc: 88.93%, Super-Class Acc: 75.69%
# Current Learning Rate: 0.041728
# Epoch 41/150, Train Loss: 2.256, Train Acc: 65.21%, Test Loss: 2.310, Test Acc: 63.11%, Top-5 Acc: 88.54%, Super-Class Acc: 74.56%
# Current Learning Rate: 0.041336
# Epoch 42/150, Train Loss: 2.250, Train Acc: 65.42%, Test Loss: 2.296, Test Acc: 63.98%, Top-5 Acc: 88.40%, Super-Class Acc: 75.42%
# Current Learning Rate: 0.040936
# Epoch 43/150, Train Loss: 2.241, Train Acc: 65.69%, Test Loss: 2.298, Test Acc: 64.19%, Top-5 Acc: 88.44%, Super-Class Acc: 75.81%
# Current Learning Rate: 0.040529
# Epoch 44/150, Train Loss: 2.236, Train Acc: 65.71%, Test Loss: 2.250, Test Acc: 66.07%, Top-5 Acc: 89.21%, Super-Class Acc: 77.05%
# Current Learning Rate: 0.040115
# Epoch 45/150, Train Loss: 2.226, Train Acc: 66.28%, Test Loss: 2.256, Test Acc: 64.84%, Top-5 Acc: 89.38%, Super-Class Acc: 77.12%
# Current Learning Rate: 0.039695
# Epoch 46/150, Train Loss: 2.222, Train Acc: 66.33%, Test Loss: 2.221, Test Acc: 66.03%, Top-5 Acc: 90.06%, Super-Class Acc: 77.88%
# Current Learning Rate: 0.039268
# Epoch 47/150, Train Loss: 2.210, Train Acc: 66.45%, Test Loss: 2.237, Test Acc: 65.77%, Top-5 Acc: 89.58%, Super-Class Acc: 76.75%
# Current Learning Rate: 0.038835
# Epoch 48/150, Train Loss: 2.206, Train Acc: 67.03%, Test Loss: 2.266, Test Acc: 64.84%, Top-5 Acc: 88.48%, Super-Class Acc: 76.27%
# Current Learning Rate: 0.038396
# Epoch 49/150, Train Loss: 2.193, Train Acc: 67.36%, Test Loss: 2.211, Test Acc: 66.51%, Top-5 Acc: 89.80%, Super-Class Acc: 77.98%
# Current Learning Rate: 0.037951
# Epoch 50/150, Train Loss: 2.177, Train Acc: 67.99%, Test Loss: 2.254, Test Acc: 66.05%, Top-5 Acc: 88.70%, Super-Class Acc: 77.11%
# Current Learning Rate: 0.037500
# Epoch 51/150, Train Loss: 2.179, Train Acc: 67.92%, Test Loss: 2.188, Test Acc: 67.52%, Top-5 Acc: 90.04%, Super-Class Acc: 78.32%
# Current Learning Rate: 0.037044
# Epoch 52/150, Train Loss: 2.170, Train Acc: 68.30%, Test Loss: 2.237, Test Acc: 65.69%, Top-5 Acc: 89.13%, Super-Class Acc: 77.35%
# Current Learning Rate: 0.036582
# Epoch 53/150, Train Loss: 2.167, Train Acc: 68.30%, Test Loss: 2.220, Test Acc: 66.44%, Top-5 Acc: 89.83%, Super-Class Acc: 77.30%
# Current Learning Rate: 0.036116
# Epoch 54/150, Train Loss: 2.154, Train Acc: 68.46%, Test Loss: 2.187, Test Acc: 67.93%, Top-5 Acc: 89.96%, Super-Class Acc: 78.83%
# Current Learning Rate: 0.035644
# Epoch 55/150, Train Loss: 2.146, Train Acc: 68.98%, Test Loss: 2.242, Test Acc: 65.62%, Top-5 Acc: 89.67%, Super-Class Acc: 76.86%
# Current Learning Rate: 0.035168
# Epoch 56/150, Train Loss: 2.143, Train Acc: 69.00%, Test Loss: 2.219, Test Acc: 66.65%, Top-5 Acc: 89.96%, Super-Class Acc: 77.66%
# Current Learning Rate: 0.034688
# Epoch 57/150, Train Loss: 2.133, Train Acc: 69.18%, Test Loss: 2.217, Test Acc: 66.61%, Top-5 Acc: 89.74%, Super-Class Acc: 77.84%
# Current Learning Rate: 0.034203
# Epoch 58/150, Train Loss: 2.123, Train Acc: 69.63%, Test Loss: 2.210, Test Acc: 66.94%, Top-5 Acc: 89.73%, Super-Class Acc: 77.73%
# Current Learning Rate: 0.033714
# Epoch 59/150, Train Loss: 2.115, Train Acc: 70.18%, Test Loss: 2.194, Test Acc: 66.97%, Top-5 Acc: 90.20%, Super-Class Acc: 78.27%
# Current Learning Rate: 0.033222
# Epoch 60/150, Train Loss: 2.102, Train Acc: 70.48%, Test Loss: 2.167, Test Acc: 67.69%, Top-5 Acc: 90.61%, Super-Class Acc: 79.09%
# Current Learning Rate: 0.032725
# Epoch 61/150, Train Loss: 2.096, Train Acc: 70.46%, Test Loss: 2.186, Test Acc: 67.78%, Top-5 Acc: 90.25%, Super-Class Acc: 79.03%
# Current Learning Rate: 0.032226
# Epoch 62/150, Train Loss: 2.091, Train Acc: 70.87%, Test Loss: 2.167, Test Acc: 68.06%, Top-5 Acc: 90.34%, Super-Class Acc: 79.12%
# Current Learning Rate: 0.031723
# Epoch 63/150, Train Loss: 2.083, Train Acc: 71.14%, Test Loss: 2.157, Test Acc: 68.81%, Top-5 Acc: 90.64%, Super-Class Acc: 79.56%
# Current Learning Rate: 0.031217
# Epoch 64/150, Train Loss: 2.074, Train Acc: 71.40%, Test Loss: 2.212, Test Acc: 66.81%, Top-5 Acc: 89.95%, Super-Class Acc: 77.77%
# Current Learning Rate: 0.030709
# Epoch 65/150, Train Loss: 2.070, Train Acc: 71.47%, Test Loss: 2.194, Test Acc: 67.16%, Top-5 Acc: 89.97%, Super-Class Acc: 78.13%
# Current Learning Rate: 0.030198
# Epoch 66/150, Train Loss: 2.057, Train Acc: 71.98%, Test Loss: 2.126, Test Acc: 69.65%, Top-5 Acc: 91.04%, Super-Class Acc: 80.38%
# Current Learning Rate: 0.029685
# Epoch 67/150, Train Loss: 2.044, Train Acc: 72.54%, Test Loss: 2.197, Test Acc: 67.17%, Top-5 Acc: 89.88%, Super-Class Acc: 78.26%
# Current Learning Rate: 0.029169
# Epoch 68/150, Train Loss: 2.037, Train Acc: 72.58%, Test Loss: 2.171, Test Acc: 67.80%, Top-5 Acc: 90.32%, Super-Class Acc: 78.88%
# Current Learning Rate: 0.028652
# Epoch 69/150, Train Loss: 2.030, Train Acc: 72.76%, Test Loss: 2.175, Test Acc: 68.00%, Top-5 Acc: 90.44%, Super-Class Acc: 78.68%
# Current Learning Rate: 0.028133
# Epoch 70/150, Train Loss: 2.022, Train Acc: 73.27%, Test Loss: 2.182, Test Acc: 68.21%, Top-5 Acc: 90.52%, Super-Class Acc: 78.94%
# Current Learning Rate: 0.027613
# Epoch 71/150, Train Loss: 2.014, Train Acc: 73.38%, Test Loss: 2.159, Test Acc: 68.69%, Top-5 Acc: 90.54%, Super-Class Acc: 79.02%
# Current Learning Rate: 0.027092
# Epoch 72/150, Train Loss: 1.999, Train Acc: 73.87%, Test Loss: 2.153, Test Acc: 68.86%, Top-5 Acc: 90.67%, Super-Class Acc: 79.79%
# Current Learning Rate: 0.026570
# Epoch 73/150, Train Loss: 1.991, Train Acc: 74.29%, Test Loss: 2.149, Test Acc: 69.31%, Top-5 Acc: 90.71%, Super-Class Acc: 80.16%
# Current Learning Rate: 0.026047
# Epoch 74/150, Train Loss: 1.989, Train Acc: 74.33%, Test Loss: 2.117, Test Acc: 70.14%, Top-5 Acc: 90.59%, Super-Class Acc: 80.24%
# Current Learning Rate: 0.025524
# Epoch 75/150, Train Loss: 1.971, Train Acc: 74.95%, Test Loss: 2.153, Test Acc: 68.60%, Top-5 Acc: 90.78%, Super-Class Acc: 79.37%
# Current Learning Rate: 0.025000
# Epoch 76/150, Train Loss: 1.967, Train Acc: 75.31%, Test Loss: 2.126, Test Acc: 69.70%, Top-5 Acc: 90.94%, Super-Class Acc: 80.08%
# Current Learning Rate: 0.024476
# Epoch 77/150, Train Loss: 1.954, Train Acc: 75.77%, Test Loss: 2.119, Test Acc: 69.48%, Top-5 Acc: 91.17%, Super-Class Acc: 79.63%
# Current Learning Rate: 0.023953
# Epoch 78/150, Train Loss: 1.952, Train Acc: 75.89%, Test Loss: 2.148, Test Acc: 68.82%, Top-5 Acc: 90.55%, Super-Class Acc: 78.94%
# Current Learning Rate: 0.023430
# Epoch 79/150, Train Loss: 1.934, Train Acc: 76.45%, Test Loss: 2.134, Test Acc: 69.65%, Top-5 Acc: 91.17%, Super-Class Acc: 80.18%
# Current Learning Rate: 0.022908
# Epoch 80/150, Train Loss: 1.921, Train Acc: 77.07%, Test Loss: 2.141, Test Acc: 69.42%, Top-5 Acc: 90.79%, Super-Class Acc: 79.65%
# Current Learning Rate: 0.022387
# Epoch 81/150, Train Loss: 1.916, Train Acc: 76.98%, Test Loss: 2.136, Test Acc: 70.07%, Top-5 Acc: 91.23%, Super-Class Acc: 80.47%
# Current Learning Rate: 0.021867
# Epoch 82/150, Train Loss: 1.896, Train Acc: 77.73%, Test Loss: 2.115, Test Acc: 70.28%, Top-5 Acc: 91.10%, Super-Class Acc: 80.61%
# Current Learning Rate: 0.021348
# Epoch 83/150, Train Loss: 1.894, Train Acc: 77.65%, Test Loss: 2.106, Test Acc: 71.08%, Top-5 Acc: 91.18%, Super-Class Acc: 81.04%
# Current Learning Rate: 0.020831
# Epoch 84/150, Train Loss: 1.886, Train Acc: 77.98%, Test Loss: 2.160, Test Acc: 69.16%, Top-5 Acc: 90.36%, Super-Class Acc: 80.13%
# Current Learning Rate: 0.020315
# Epoch 85/150, Train Loss: 1.871, Train Acc: 78.78%, Test Loss: 2.119, Test Acc: 70.25%, Top-5 Acc: 91.27%, Super-Class Acc: 80.61%
# Current Learning Rate: 0.019802
# Epoch 86/150, Train Loss: 1.861, Train Acc: 78.95%, Test Loss: 2.130, Test Acc: 69.96%, Top-5 Acc: 90.92%, Super-Class Acc: 80.53%
# Current Learning Rate: 0.019291
# Epoch 87/150, Train Loss: 1.843, Train Acc: 79.53%, Test Loss: 2.099, Test Acc: 70.73%, Top-5 Acc: 91.54%, Super-Class Acc: 80.61%
# Current Learning Rate: 0.018783
# Epoch 88/150, Train Loss: 1.848, Train Acc: 79.56%, Test Loss: 2.154, Test Acc: 69.28%, Top-5 Acc: 90.42%, Super-Class Acc: 79.64%
# Current Learning Rate: 0.018277
# Epoch 89/150, Train Loss: 1.832, Train Acc: 80.06%, Test Loss: 2.123, Test Acc: 70.29%, Top-5 Acc: 91.10%, Super-Class Acc: 80.81%
# Current Learning Rate: 0.017774
# Epoch 90/150, Train Loss: 1.818, Train Acc: 80.56%, Test Loss: 2.108, Test Acc: 71.07%, Top-5 Acc: 90.68%, Super-Class Acc: 81.04%
# Current Learning Rate: 0.017275
# Epoch 91/150, Train Loss: 1.808, Train Acc: 81.04%, Test Loss: 2.120, Test Acc: 70.65%, Top-5 Acc: 90.81%, Super-Class Acc: 81.10%
# Current Learning Rate: 0.016778
# Epoch 92/150, Train Loss: 1.799, Train Acc: 81.31%, Test Loss: 2.108, Test Acc: 70.94%, Top-5 Acc: 90.89%, Super-Class Acc: 80.81%
# Current Learning Rate: 0.016286
# Epoch 93/150, Train Loss: 1.791, Train Acc: 81.55%, Test Loss: 2.105, Test Acc: 71.50%, Top-5 Acc: 91.13%, Super-Class Acc: 81.70%
# Current Learning Rate: 0.015797
# Epoch 94/150, Train Loss: 1.773, Train Acc: 82.28%, Test Loss: 2.081, Test Acc: 71.50%, Top-5 Acc: 91.47%, Super-Class Acc: 81.48%
# Current Learning Rate: 0.015312
# Epoch 95/150, Train Loss: 1.762, Train Acc: 82.83%, Test Loss: 2.112, Test Acc: 71.20%, Top-5 Acc: 90.77%, Super-Class Acc: 81.39%
# Current Learning Rate: 0.014832
# Epoch 96/150, Train Loss: 1.743, Train Acc: 83.20%, Test Loss: 2.098, Test Acc: 71.29%, Top-5 Acc: 91.14%, Super-Class Acc: 81.38%
# Current Learning Rate: 0.014356
# Epoch 97/150, Train Loss: 1.732, Train Acc: 83.82%, Test Loss: 2.089, Test Acc: 71.70%, Top-5 Acc: 91.62%, Super-Class Acc: 81.48%
# Current Learning Rate: 0.013884
# Epoch 98/150, Train Loss: 1.724, Train Acc: 83.97%, Test Loss: 2.081, Test Acc: 72.47%, Top-5 Acc: 91.37%, Super-Class Acc: 82.13%
# Current Learning Rate: 0.013418
# Epoch 99/150, Train Loss: 1.719, Train Acc: 84.28%, Test Loss: 2.100, Test Acc: 71.82%, Top-5 Acc: 91.44%, Super-Class Acc: 81.49%
# Current Learning Rate: 0.012956
# Epoch 100/150, Train Loss: 1.701, Train Acc: 84.85%, Test Loss: 2.075, Test Acc: 72.33%, Top-5 Acc: 91.42%, Super-Class Acc: 82.20%
# Current Learning Rate: 0.012500
# Epoch 101/150, Train Loss: 1.690, Train Acc: 85.32%, Test Loss: 2.094, Test Acc: 72.42%, Top-5 Acc: 91.13%, Super-Class Acc: 82.13%
# Current Learning Rate: 0.012049
# Epoch 102/150, Train Loss: 1.677, Train Acc: 85.86%, Test Loss: 2.089, Test Acc: 71.86%, Top-5 Acc: 91.40%, Super-Class Acc: 81.56%
# Current Learning Rate: 0.011604
# Epoch 103/150, Train Loss: 1.668, Train Acc: 86.07%, Test Loss: 2.097, Test Acc: 71.76%, Top-5 Acc: 91.05%, Super-Class Acc: 81.93%
# Current Learning Rate: 0.011165
# Epoch 104/150, Train Loss: 1.656, Train Acc: 86.62%, Test Loss: 2.089, Test Acc: 72.00%, Top-5 Acc: 91.21%, Super-Class Acc: 82.10%
# Current Learning Rate: 0.010732
# Epoch 105/150, Train Loss: 1.640, Train Acc: 87.36%, Test Loss: 2.073, Test Acc: 72.90%, Top-5 Acc: 91.47%, Super-Class Acc: 82.10%
# Current Learning Rate: 0.010305
# Epoch 106/150, Train Loss: 1.632, Train Acc: 87.65%, Test Loss: 2.087, Test Acc: 72.27%, Top-5 Acc: 91.40%, Super-Class Acc: 81.99%
# Current Learning Rate: 0.009885
# Epoch 107/150, Train Loss: 1.618, Train Acc: 88.21%, Test Loss: 2.082, Test Acc: 72.40%, Top-5 Acc: 91.45%, Super-Class Acc: 82.40%
# Current Learning Rate: 0.009471
# Epoch 108/150, Train Loss: 1.601, Train Acc: 88.70%, Test Loss: 2.076, Test Acc: 72.76%, Top-5 Acc: 91.23%, Super-Class Acc: 82.40%
# Current Learning Rate: 0.009064
# Epoch 109/150, Train Loss: 1.596, Train Acc: 88.87%, Test Loss: 2.067, Test Acc: 73.75%, Top-5 Acc: 91.49%, Super-Class Acc: 83.35%
# Current Learning Rate: 0.008664
# Epoch 110/150, Train Loss: 1.581, Train Acc: 89.54%, Test Loss: 2.058, Test Acc: 73.65%, Top-5 Acc: 91.88%, Super-Class Acc: 83.35%
# Current Learning Rate: 0.008272
# Epoch 111/150, Train Loss: 1.569, Train Acc: 89.92%, Test Loss: 2.049, Test Acc: 73.70%, Top-5 Acc: 91.93%, Super-Class Acc: 83.24%
# Current Learning Rate: 0.007886
# Epoch 112/150, Train Loss: 1.554, Train Acc: 90.59%, Test Loss: 2.051, Test Acc: 73.93%, Top-5 Acc: 91.55%, Super-Class Acc: 83.49%
# Current Learning Rate: 0.007508
# Epoch 113/150, Train Loss: 1.544, Train Acc: 90.86%, Test Loss: 2.078, Test Acc: 72.91%, Top-5 Acc: 91.64%, Super-Class Acc: 82.91%
# Current Learning Rate: 0.007138
# Epoch 114/150, Train Loss: 1.536, Train Acc: 91.19%, Test Loss: 2.061, Test Acc: 74.19%, Top-5 Acc: 91.54%, Super-Class Acc: 83.30%
# Current Learning Rate: 0.006776
# Epoch 115/150, Train Loss: 1.515, Train Acc: 92.03%, Test Loss: 2.033, Test Acc: 74.71%, Top-5 Acc: 91.77%, Super-Class Acc: 83.84%
# Current Learning Rate: 0.006421
# Epoch 116/150, Train Loss: 1.510, Train Acc: 92.02%, Test Loss: 2.053, Test Acc: 73.79%, Top-5 Acc: 91.87%, Super-Class Acc: 83.43%
# Current Learning Rate: 0.006075
# Epoch 117/150, Train Loss: 1.490, Train Acc: 92.89%, Test Loss: 2.054, Test Acc: 73.98%, Top-5 Acc: 91.69%, Super-Class Acc: 83.21%
# Current Learning Rate: 0.005737
# Epoch 118/150, Train Loss: 1.485, Train Acc: 93.09%, Test Loss: 2.040, Test Acc: 74.72%, Top-5 Acc: 91.81%, Super-Class Acc: 83.65%
# Current Learning Rate: 0.005408
# Epoch 119/150, Train Loss: 1.473, Train Acc: 93.50%, Test Loss: 2.022, Test Acc: 74.99%, Top-5 Acc: 92.10%, Super-Class Acc: 83.63%
# Current Learning Rate: 0.005087
# Epoch 120/150, Train Loss: 1.459, Train Acc: 94.03%, Test Loss: 2.035, Test Acc: 75.38%, Top-5 Acc: 92.04%, Super-Class Acc: 84.60%
# Current Learning Rate: 0.004775
# Epoch 121/150, Train Loss: 1.454, Train Acc: 94.11%, Test Loss: 2.033, Test Acc: 74.95%, Top-5 Acc: 92.04%, Super-Class Acc: 83.86%
# Current Learning Rate: 0.004471
# Epoch 122/150, Train Loss: 1.437, Train Acc: 94.87%, Test Loss: 2.033, Test Acc: 75.37%, Top-5 Acc: 92.03%, Super-Class Acc: 84.43%
# Current Learning Rate: 0.004177
# Epoch 123/150, Train Loss: 1.432, Train Acc: 95.06%, Test Loss: 2.029, Test Acc: 75.63%, Top-5 Acc: 91.57%, Super-Class Acc: 84.40%
# Current Learning Rate: 0.003892
# Epoch 124/150, Train Loss: 1.423, Train Acc: 95.37%, Test Loss: 2.022, Test Acc: 75.61%, Top-5 Acc: 91.74%, Super-Class Acc: 84.45%
# Current Learning Rate: 0.003616
# Epoch 125/150, Train Loss: 1.414, Train Acc: 95.58%, Test Loss: 2.008, Test Acc: 76.02%, Top-5 Acc: 92.15%, Super-Class Acc: 84.71%
# Current Learning Rate: 0.003349
# Epoch 126/150, Train Loss: 1.404, Train Acc: 95.92%, Test Loss: 2.001, Test Acc: 76.11%, Top-5 Acc: 92.18%, Super-Class Acc: 84.93%
# Current Learning Rate: 0.003092
# Epoch 127/150, Train Loss: 1.395, Train Acc: 96.26%, Test Loss: 2.013, Test Acc: 76.04%, Top-5 Acc: 91.87%, Super-Class Acc: 84.92%
# Current Learning Rate: 0.002845
# Epoch 128/150, Train Loss: 1.389, Train Acc: 96.56%, Test Loss: 1.996, Test Acc: 76.38%, Top-5 Acc: 92.12%, Super-Class Acc: 85.07%
# Current Learning Rate: 0.002607
# Epoch 129/150, Train Loss: 1.382, Train Acc: 96.75%, Test Loss: 1.989, Test Acc: 76.98%, Top-5 Acc: 92.27%, Super-Class Acc: 85.59%
# Current Learning Rate: 0.002379
# Epoch 130/150, Train Loss: 1.372, Train Acc: 97.09%, Test Loss: 1.989, Test Acc: 76.88%, Top-5 Acc: 92.43%, Super-Class Acc: 85.21%
# Current Learning Rate: 0.002161
# Epoch 131/150, Train Loss: 1.369, Train Acc: 97.15%, Test Loss: 1.987, Test Acc: 76.73%, Top-5 Acc: 92.35%, Super-Class Acc: 85.19%
# Current Learning Rate: 0.001953
# Epoch 132/150, Train Loss: 1.361, Train Acc: 97.42%, Test Loss: 1.988, Test Acc: 76.93%, Top-5 Acc: 92.39%, Super-Class Acc: 85.63%
# Current Learning Rate: 0.001756
# Epoch 133/150, Train Loss: 1.359, Train Acc: 97.54%, Test Loss: 1.977, Test Acc: 76.91%, Top-5 Acc: 92.49%, Super-Class Acc: 85.60%
# Current Learning Rate: 0.001568
# Epoch 134/150, Train Loss: 1.354, Train Acc: 97.72%, Test Loss: 1.972, Test Acc: 76.94%, Top-5 Acc: 92.51%, Super-Class Acc: 85.40%
# Current Learning Rate: 0.001391
# Epoch 135/150, Train Loss: 1.348, Train Acc: 97.89%, Test Loss: 1.969, Test Acc: 77.51%, Top-5 Acc: 92.77%, Super-Class Acc: 85.80%
# Current Learning Rate: 0.001224
# Epoch 136/150, Train Loss: 1.346, Train Acc: 97.93%, Test Loss: 1.963, Test Acc: 77.37%, Top-5 Acc: 92.57%, Super-Class Acc: 85.97%
# Current Learning Rate: 0.001067
# Epoch 137/150, Train Loss: 1.343, Train Acc: 98.07%, Test Loss: 1.962, Test Acc: 77.72%, Top-5 Acc: 92.68%, Super-Class Acc: 85.85%
# Current Learning Rate: 0.000921
# Epoch 138/150, Train Loss: 1.342, Train Acc: 98.06%, Test Loss: 1.957, Test Acc: 78.00%, Top-5 Acc: 92.73%, Super-Class Acc: 86.13%
# Current Learning Rate: 0.000785
# Epoch 139/150, Train Loss: 1.337, Train Acc: 98.26%, Test Loss: 1.959, Test Acc: 77.64%, Top-5 Acc: 92.64%, Super-Class Acc: 86.05%
# Current Learning Rate: 0.000661
# Epoch 140/150, Train Loss: 1.335, Train Acc: 98.32%, Test Loss: 1.959, Test Acc: 78.14%, Top-5 Acc: 92.77%, Super-Class Acc: 86.35%
# Current Learning Rate: 0.000546
# Epoch 141/150, Train Loss: 1.333, Train Acc: 98.52%, Test Loss: 1.956, Test Acc: 78.19%, Top-5 Acc: 92.86%, Super-Class Acc: 86.37%
# Current Learning Rate: 0.000443
# Epoch 142/150, Train Loss: 1.332, Train Acc: 98.41%, Test Loss: 1.953, Test Acc: 78.00%, Top-5 Acc: 92.74%, Super-Class Acc: 86.05%
# Current Learning Rate: 0.000350
# Epoch 143/150, Train Loss: 1.329, Train Acc: 98.49%, Test Loss: 1.950, Test Acc: 78.15%, Top-5 Acc: 92.89%, Super-Class Acc: 86.29%
# Current Learning Rate: 0.000268
# Epoch 144/150, Train Loss: 1.329, Train Acc: 98.49%, Test Loss: 1.951, Test Acc: 78.37%, Top-5 Acc: 92.86%, Super-Class Acc: 86.48%
# Current Learning Rate: 0.000197
# Epoch 145/150, Train Loss: 1.329, Train Acc: 98.51%, Test Loss: 1.954, Test Acc: 78.15%, Top-5 Acc: 92.74%, Super-Class Acc: 86.34%
# Current Learning Rate: 0.000137
# Epoch 146/150, Train Loss: 1.327, Train Acc: 98.58%, Test Loss: 1.951, Test Acc: 78.13%, Top-5 Acc: 92.87%, Super-Class Acc: 86.15%
# Current Learning Rate: 0.000088
# Epoch 147/150, Train Loss: 1.328, Train Acc: 98.52%, Test Loss: 1.952, Test Acc: 78.15%, Top-5 Acc: 92.73%, Super-Class Acc: 86.22%
# Current Learning Rate: 0.000049
# Epoch 148/150, Train Loss: 1.326, Train Acc: 98.64%, Test Loss: 1.950, Test Acc: 78.27%, Top-5 Acc: 92.83%, Super-Class Acc: 86.44%
# Current Learning Rate: 0.000022
# Epoch 149/150, Train Loss: 1.327, Train Acc: 98.49%, Test Loss: 1.945, Test Acc: 78.21%, Top-5 Acc: 92.88%, Super-Class Acc: 86.37%
# Current Learning Rate: 0.000005
# Epoch 150/150, Train Loss: 1.325, Train Acc: 98.67%, Test Loss: 1.947, Test Acc: 78.32%, Top-5 Acc: 92.84%, Super-Class Acc: 86.37%
# Current Learning Rate: 0.000000
# Finished Training in 179m 7s
# Best Test Results:
# Epoch 144, Train Loss: 1.329, Train Acc: 98.49%, Test Loss: 1.951, Test Acc: 78.37%, Top-5 Acc: 92.86%, Super-Class Acc: 86.48%

# %%
plot_training_metrics(train_losses, test_losses, train_accuracies, test_accuracies)

# %%
import torch
import numpy as np

def evaluate_and_report_top_bottom_k(model, testloader, class_names, device='cuda', k=5):
    # CIFAR-100 一共有 100 个类别
    num_classes = len(class_names)

    # 初始化每个类别的正确预测和总样本数统计
    class_correct = np.zeros(num_classes)
    class_total = np.zeros(num_classes)

    model.eval()  # 设置模型为评估模式
    with torch.no_grad():  # 禁用梯度计算
        for images, labels in testloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)  # 获取预测的类别
            correct = (predicted == labels)  # 预测是否正确

            # 统计每个类别的正确预测数和总样本数
            for i in range(len(labels)):
                label = labels[i].item()  # 真实标签
                class_correct[label] += correct[i].item()  # 累加该类别的正确预测数
                class_total[label] += 1  # 累加该类别的总样本数

    # 计算每个类别的准确率
    class_accuracy = 100 * class_correct / class_total

    # 获取最高准确率的前 k 个类别的索引
    top_k_indices = np.argsort(class_accuracy)[-k:][::-1]  # 降序排列
    # 获取最低准确率的前 k 个类别的索引
    bottom_k_indices = np.argsort(class_accuracy)[:k]  # 升序排列

    # 输出最高的 k 个类别及其准确率
    print(f"Top {k} classes with highest accuracy:")
    for idx in top_k_indices:
        print(f"Class {class_names[idx]}: Accuracy = {class_accuracy[idx]:.2f}%")

    print("\n" + "="*30 + "\n")  # 分隔线

    # 输出最低的 k 个类别及其准确率
    print(f"Bottom {k} classes with lowest accuracy:")
    for idx in bottom_k_indices:
        print(f"Class {class_names[idx]}: Accuracy = {class_accuracy[idx]:.2f}%")

    return class_accuracy

# %%
# 假设你已经定义了 resnet 模型和 testloader
# 获取 CIFAR-100 的类别名称
cifar100_classes = torchvision.datasets.CIFAR100(root='data', download=True).classes

# 运行评估并输出最高和最低的5个类别的准确率
evaluate_and_report_top_bottom_k(resnet, testloader, cifar100_classes, device='cuda', k=5)
# Out:
# Files already downloaded and verified
# Top 5 classes with highest accuracy:
# Class road: Accuracy = 97.00%
# Class wardrobe: Accuracy = 96.00%
# Class chimpanzee: Accuracy = 93.00%
# Class skyscraper: Accuracy = 93.00%
# Class keyboard: Accuracy = 93.00%
#
# ==============================
#
# Bottom 5 classes with lowest accuracy:
# Class otter: Accuracy = 48.00%
# Class seal: Accuracy = 52.00%
# Class girl: Accuracy = 55.00%
# Class boy: Accuracy = 57.00%
# Class bowl: Accuracy = 58.00%
# array([85., 88., 62., 68., 65., 85., 83., 69., 91., 91., 58., 57., 82.,
#        73., 77., 86., 72., 84., 76., 65., 88., 93., 79., 87., 82., 72.,
#        73., 60., 85., 79., 69., 77., 72., 69., 77., 55., 89., 78., 77.,
#        93., 77., 91., 72., 92., 60., 63., 58., 73., 92., 92., 59., 80.,
#        72., 89., 77., 48., 90., 77., 88., 71., 83., 80., 75., 77., 62.,
#        68., 84., 68., 97., 80., 63., 81., 52., 64., 60., 88., 93., 71.,
#        71., 81., 61., 85., 89., 66., 76., 92., 83., 88., 80., 86., 81.,
#        84., 64., 69., 96., 75., 72., 83., 59., 82.])

# %%
import torch
import torchvision
import matplotlib.pyplot as plt

# 假设你已经定义了 resnet 模型和 testloader
# 获取 CIFAR-100 的类别名称
cifar100_classes = torchvision.datasets.CIFAR100(root='data', download=True).classes

def evaluate_and_report_top_bottom_k(model, dataloader, class_names, device='cuda', k=5):
    model.eval()
    correct = [0] * len(class_names)
    total = [0] * len(class_names)

    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, predicted = torch.max(outputs, 1)

            # 统计每个类别的正确预测数量
            for i in range(len(labels)):
                total[labels[i]] += 1
                if predicted[i] == labels[i]:
                    correct[labels[i]] += 1

    # 计算每个类别的准确率
    accuracy = [correct[i] / total[i] if total[i] > 0 else 0 for i in range(len(class_names))]

    # 找到最高和最低的 k 个类别
    top_k_indices = sorted(range(len(accuracy)), key=lambda i: accuracy[i], reverse=True)[:k]
    bottom_k_indices = sorted(range(len(accuracy)), key=lambda i: accuracy[i])[:k]

    top_k_accuracy = [accuracy[i] for i in top_k_indices]
    bottom_k_accuracy = [accuracy[i] for i in bottom_k_indices]

    # 输出最高和最低的 k 个类别及其准确率
    print("Top K Classes:")
    for i in top_k_indices:
        print(f"{class_names[i]}: {accuracy[i]:.4f}")

    print("\nBottom K Classes:")
    for i in bottom_k_indices:
        print(f"{class_names[i]}: {accuracy[i]:.4f}")

    return top_k_indices, bottom_k_indices, top_k_accuracy, bottom_k_accuracy

# 运行评估
top_k_indices, bottom_k_indices, top_k_accuracy, bottom_k_accuracy = evaluate_and_report_top_bottom_k(
    resnet, testloader, cifar100_classes, device='cuda', k=5
)

# 绘制图像
def plot_accuracy(top_classes, bottom_classes, top_accuracy, bottom_accuracy, class_names):
    plt.figure(figsize=(12, 6))

    # 绘制最高准确率的类别
    plt.subplot(1, 2, 1)
    plt.barh(range(len(top_classes)), top_accuracy, align='center')
    plt.yticks(range(len(top_classes)), [class_names[i] for i in top_classes])
    plt.xlabel('Accuracy')
    plt.title('Top 5 Classes Accuracy')

    # 绘制最低准确率的类别
    plt.subplot(1, 2, 2)
    plt.barh(range(len(bottom_classes)), bottom_accuracy, align='center')
    plt.yticks(range(len(bottom_classes)), [class_names[i] for i in bottom_classes])
    plt.xlabel('Accuracy')
    plt.title('Bottom 5 Classes Accuracy')

    plt.tight_layout()
    plt.show()

# 绘制准确率图像
plot_accuracy(top_k_indices, bottom_k_indices, top_k_accuracy, bottom_k_accuracy, cifar100_classes)
# Out:
# Files already downloaded and verified
# Top K Classes:
# road: 0.9700
# wardrobe: 0.9600
# chimpanzee: 0.9300
# keyboard: 0.9300
# skyscraper: 0.9300
#
# Bottom K Classes:
# otter: 0.4800
# seal: 0.5200
# girl: 0.5500
# boy: 0.5700
# bowl: 0.5800

# %%
import random
import matplotlib.pyplot as plt
import torchvision.transforms as transforms

def show_random_samples_from_bottom_k_classes(model, dataloader, class_names, bottom_k_indices, k=5, device='cuda'):
    # 用于转换图像的函数
    transform = transforms.ToPILImage()
    samples = {class_names[i]: [] for i in bottom_k_indices}

    # 从数据集中收集每个类别的图像
    for images, labels in dataloader:
        images, labels = images.to(device), labels.to(device)
        
        for i in range(len(labels)):
            if class_names[labels[i]] in samples and len(samples[class_names[labels[i]]]) < k:
                samples[class_names[labels[i]]].append(images[i])

    # 随机选择每个类别的样本
    selected_samples = {cls: random.sample(imgs, min(len(imgs), k)) for cls, imgs in samples.items()}

    # 绘制随机样本
    plt.figure(figsize=(15, 8))
    for i, (cls, imgs) in enumerate(selected_samples.items()):
        for j, img in enumerate(imgs):
            plt.subplot(len(selected_samples), k, i * k + j + 1)
            plt.imshow(transform(img.cpu()))
            plt.axis('off')
            plt.title(cls)

    plt.tight_layout()
    plt.show()

# 调用函数展示最低准确率类别的随机图片
show_random_samples_from_bottom_k_classes(resnet, testloader, cifar100_classes, bottom_k_indices, k=5, device='cuda')

# %%
#label_smoothing_loss，smoothing=0.175，momentum=0.95，bitch_size=32，nesterov=True，ReduceLROnPlateau 调度器

# 使用 SGD 优化器
optimizer = optim.SGD(
    resnet.parameters(),
    lr=0.01,
    momentum=0.95,
    weight_decay=0.0001,
    nesterov=True
)

# 训练过程
train_losses, test_losses, train_accuracies, test_accuracies = train(
    resnet, 
    trainloader, 
    testloader, 
    label_smoothing_loss,  # 使用标签平滑损失
    optimizer,
    super_class_mapping,  # 添加super_class_mapping
    class_to_superclass,  # 添加class_to_superclass
    device='cuda', 
    num_epochs=80,  # 设置为30个epoch
    patience=3,  # 即使设置了patience，也不会触发早停法
    min_delta=0.5, 
    use_early_stopping=False  # 不使用早停法
)
# Out:
# Epoch 1/80, Train Loss: 4.260, Train Acc: 9.12%, Test Loss: 3.765, Test Acc: 19.21%, Top-5 Acc: 46.06%, Super-Class Acc: 32.88%
# Epoch 2/80, Train Loss: 3.768, Train Acc: 19.78%, Test Loss: 3.356, Test Acc: 31.81%, Top-5 Acc: 62.42%, Super-Class Acc: 46.21%
# Epoch 3/80, Train Loss: 3.453, Train Acc: 28.63%, Test Loss: 3.091, Test Acc: 40.05%, Top-5 Acc: 71.64%, Super-Class Acc: 55.00%
# Epoch 4/80, Train Loss: 3.229, Train Acc: 35.51%, Test Loss: 2.954, Test Acc: 44.89%, Top-5 Acc: 75.01%, Super-Class Acc: 58.58%
# Epoch 5/80, Train Loss: 3.075, Train Acc: 40.23%, Test Loss: 2.847, Test Acc: 49.48%, Top-5 Acc: 78.61%, Super-Class Acc: 62.93%
# Epoch 6/80, Train Loss: 2.956, Train Acc: 44.02%, Test Loss: 2.730, Test Acc: 52.44%, Top-5 Acc: 81.58%, Super-Class Acc: 65.15%
# Epoch 7/80, Train Loss: 2.874, Train Acc: 46.87%, Test Loss: 2.698, Test Acc: 53.51%, Top-5 Acc: 81.77%, Super-Class Acc: 65.87%
# Epoch 8/80, Train Loss: 2.788, Train Acc: 49.52%, Test Loss: 2.626, Test Acc: 56.16%, Top-5 Acc: 83.87%, Super-Class Acc: 68.39%
# Epoch 9/80, Train Loss: 2.726, Train Acc: 51.94%, Test Loss: 2.593, Test Acc: 57.68%, Top-5 Acc: 84.96%, Super-Class Acc: 70.20%
# Epoch 10/80, Train Loss: 2.672, Train Acc: 53.62%, Test Loss: 2.551, Test Acc: 57.70%, Top-5 Acc: 85.29%, Super-Class Acc: 69.72%
# Epoch 11/80, Train Loss: 2.621, Train Acc: 55.52%, Test Loss: 2.471, Test Acc: 61.29%, Top-5 Acc: 87.24%, Super-Class Acc: 73.86%
# Epoch 12/80, Train Loss: 2.584, Train Acc: 56.72%, Test Loss: 2.467, Test Acc: 61.41%, Top-5 Acc: 87.18%, Super-Class Acc: 73.41%
# Epoch 13/80, Train Loss: 2.544, Train Acc: 58.36%, Test Loss: 2.428, Test Acc: 62.52%, Top-5 Acc: 88.00%, Super-Class Acc: 74.00%
# Epoch 14/80, Train Loss: 2.510, Train Acc: 59.31%, Test Loss: 2.412, Test Acc: 63.23%, Top-5 Acc: 88.22%, Super-Class Acc: 74.78%
# Epoch 15/80, Train Loss: 2.482, Train Acc: 60.24%, Test Loss: 2.404, Test Acc: 63.85%, Top-5 Acc: 88.30%, Super-Class Acc: 75.46%
# Epoch 16/80, Train Loss: 2.456, Train Acc: 61.02%, Test Loss: 2.395, Test Acc: 64.07%, Top-5 Acc: 88.53%, Super-Class Acc: 75.87%
# Epoch 17/80, Train Loss: 2.431, Train Acc: 62.02%, Test Loss: 2.365, Test Acc: 64.80%, Top-5 Acc: 89.03%, Super-Class Acc: 76.67%
# Epoch 18/80, Train Loss: 2.411, Train Acc: 62.83%, Test Loss: 2.361, Test Acc: 65.81%, Top-5 Acc: 89.38%, Super-Class Acc: 77.13%
# Epoch 19/80, Train Loss: 2.390, Train Acc: 63.70%, Test Loss: 2.392, Test Acc: 64.07%, Top-5 Acc: 88.54%, Super-Class Acc: 75.80%
# Epoch 20/80, Train Loss: 2.366, Train Acc: 64.74%, Test Loss: 2.385, Test Acc: 63.76%, Top-5 Acc: 88.48%, Super-Class Acc: 75.63%
# Epoch 21/80, Train Loss: 2.354, Train Acc: 65.13%, Test Loss: 2.341, Test Acc: 66.09%, Top-5 Acc: 89.83%, Super-Class Acc: 77.48%
# Epoch 22/80, Train Loss: 2.331, Train Acc: 65.44%, Test Loss: 2.350, Test Acc: 66.37%, Top-5 Acc: 89.13%, Super-Class Acc: 77.81%
# Epoch 23/80, Train Loss: 2.312, Train Acc: 66.34%, Test Loss: 2.335, Test Acc: 66.82%, Top-5 Acc: 89.72%, Super-Class Acc: 77.73%
# Epoch 24/80, Train Loss: 2.300, Train Acc: 66.88%, Test Loss: 2.323, Test Acc: 66.70%, Top-5 Acc: 90.01%, Super-Class Acc: 77.82%
# Epoch 25/80, Train Loss: 2.287, Train Acc: 67.35%, Test Loss: 2.317, Test Acc: 67.32%, Top-5 Acc: 89.71%, Super-Class Acc: 78.01%
# Epoch 26/80, Train Loss: 2.270, Train Acc: 68.17%, Test Loss: 2.323, Test Acc: 66.47%, Top-5 Acc: 89.58%, Super-Class Acc: 77.16%
# Epoch 27/80, Train Loss: 2.266, Train Acc: 68.11%, Test Loss: 2.342, Test Acc: 67.23%, Top-5 Acc: 89.31%, Super-Class Acc: 78.41%
# Epoch 28/80, Train Loss: 2.251, Train Acc: 68.88%, Test Loss: 2.324, Test Acc: 67.27%, Top-5 Acc: 89.99%, Super-Class Acc: 78.25%
# Epoch 29/80, Train Loss: 2.241, Train Acc: 69.05%, Test Loss: 2.315, Test Acc: 67.41%, Top-5 Acc: 90.08%, Super-Class Acc: 78.33%
# Epoch 30/80, Train Loss: 2.226, Train Acc: 69.59%, Test Loss: 2.304, Test Acc: 67.14%, Top-5 Acc: 90.52%, Super-Class Acc: 78.79%
# Epoch 31/80, Train Loss: 2.216, Train Acc: 70.17%, Test Loss: 2.294, Test Acc: 67.71%, Top-5 Acc: 90.49%, Super-Class Acc: 79.08%
# Epoch 32/80, Train Loss: 2.204, Train Acc: 70.82%, Test Loss: 2.285, Test Acc: 67.87%, Top-5 Acc: 90.04%, Super-Class Acc: 78.89%
# Epoch 33/80, Train Loss: 2.194, Train Acc: 71.02%, Test Loss: 2.280, Test Acc: 67.68%, Top-5 Acc: 90.39%, Super-Class Acc: 78.68%
# Epoch 34/80, Train Loss: 2.186, Train Acc: 71.30%, Test Loss: 2.296, Test Acc: 68.19%, Top-5 Acc: 89.94%, Super-Class Acc: 79.11%
# Epoch 35/80, Train Loss: 2.180, Train Acc: 71.46%, Test Loss: 2.306, Test Acc: 67.72%, Top-5 Acc: 90.09%, Super-Class Acc: 78.86%
# Epoch 36/80, Train Loss: 2.167, Train Acc: 71.85%, Test Loss: 2.271, Test Acc: 68.67%, Top-5 Acc: 90.50%, Super-Class Acc: 79.54%
# Epoch 37/80, Train Loss: 2.160, Train Acc: 71.99%, Test Loss: 2.265, Test Acc: 69.46%, Top-5 Acc: 90.80%, Super-Class Acc: 80.09%
# Epoch 38/80, Train Loss: 2.151, Train Acc: 72.64%, Test Loss: 2.282, Test Acc: 68.44%, Top-5 Acc: 90.53%, Super-Class Acc: 79.00%
# Epoch 39/80, Train Loss: 2.147, Train Acc: 73.00%, Test Loss: 2.290, Test Acc: 68.36%, Top-5 Acc: 90.17%, Super-Class Acc: 79.17%
# Epoch 40/80, Train Loss: 2.139, Train Acc: 72.92%, Test Loss: 2.256, Test Acc: 68.99%, Top-5 Acc: 90.55%, Super-Class Acc: 79.96%
# Epoch 41/80, Train Loss: 2.132, Train Acc: 73.24%, Test Loss: 2.258, Test Acc: 69.16%, Top-5 Acc: 90.93%, Super-Class Acc: 79.98%
# Epoch 42/80, Train Loss: 2.131, Train Acc: 73.33%, Test Loss: 2.263, Test Acc: 68.74%, Top-5 Acc: 90.35%, Super-Class Acc: 79.61%
# Epoch 43/80, Train Loss: 2.121, Train Acc: 73.69%, Test Loss: 2.270, Test Acc: 68.83%, Top-5 Acc: 90.53%, Super-Class Acc: 79.45%
# Epoch 44/80, Train Loss: 2.107, Train Acc: 74.22%, Test Loss: 2.260, Test Acc: 69.15%, Top-5 Acc: 90.33%, Super-Class Acc: 79.88%
# Epoch 00044: reducing learning rate of group 0 to 1.0000e-03.
# Learning Rate updated: 0.010000 -> 0.001000
# Epoch 45/80, Train Loss: 1.953, Train Acc: 80.70%, Test Loss: 2.141, Test Acc: 73.28%, Top-5 Acc: 92.60%, Super-Class Acc: 83.25%
# Epoch 46/80, Train Loss: 1.901, Train Acc: 82.92%, Test Loss: 2.131, Test Acc: 73.58%, Top-5 Acc: 92.77%, Super-Class Acc: 83.41%
# Epoch 47/80, Train Loss: 1.884, Train Acc: 83.62%, Test Loss: 2.119, Test Acc: 73.99%, Top-5 Acc: 92.85%, Super-Class Acc: 83.75%
# Epoch 48/80, Train Loss: 1.872, Train Acc: 84.25%, Test Loss: 2.117, Test Acc: 74.24%, Top-5 Acc: 92.68%, Super-Class Acc: 83.86%
# Epoch 49/80, Train Loss: 1.851, Train Acc: 85.04%, Test Loss: 2.118, Test Acc: 74.20%, Top-5 Acc: 92.62%, Super-Class Acc: 83.84%
# Epoch 50/80, Train Loss: 1.846, Train Acc: 85.19%, Test Loss: 2.114, Test Acc: 74.18%, Top-5 Acc: 92.75%, Super-Class Acc: 83.52%
# Epoch 51/80, Train Loss: 1.840, Train Acc: 85.51%, Test Loss: 2.111, Test Acc: 74.49%, Top-5 Acc: 92.90%, Super-Class Acc: 83.74%
# Epoch 52/80, Train Loss: 1.833, Train Acc: 85.67%, Test Loss: 2.116, Test Acc: 74.06%, Top-5 Acc: 92.62%, Super-Class Acc: 83.51%
# Epoch 53/80, Train Loss: 1.824, Train Acc: 86.30%, Test Loss: 2.111, Test Acc: 74.59%, Top-5 Acc: 92.52%, Super-Class Acc: 83.85%
# Epoch 54/80, Train Loss: 1.820, Train Acc: 86.40%, Test Loss: 2.111, Test Acc: 74.41%, Top-5 Acc: 92.64%, Super-Class Acc: 83.55%
# Epoch 55/80, Train Loss: 1.815, Train Acc: 86.53%, Test Loss: 2.108, Test Acc: 74.69%, Top-5 Acc: 92.58%, Super-Class Acc: 83.86%
# Epoch 56/80, Train Loss: 1.808, Train Acc: 86.80%, Test Loss: 2.110, Test Acc: 74.27%, Top-5 Acc: 92.58%, Super-Class Acc: 83.45%
# Epoch 57/80, Train Loss: 1.800, Train Acc: 87.22%, Test Loss: 2.109, Test Acc: 74.69%, Top-5 Acc: 92.56%, Super-Class Acc: 83.67%
# Epoch 58/80, Train Loss: 1.801, Train Acc: 87.15%, Test Loss: 2.110, Test Acc: 74.50%, Top-5 Acc: 92.60%, Super-Class Acc: 83.57%
# Epoch 59/80, Train Loss: 1.795, Train Acc: 87.37%, Test Loss: 2.109, Test Acc: 74.49%, Top-5 Acc: 92.66%, Super-Class Acc: 83.49%
# Epoch 00059: reducing learning rate of group 0 to 1.0000e-04.
# Learning Rate updated: 0.001000 -> 0.000100
# Epoch 60/80, Train Loss: 1.780, Train Acc: 88.02%, Test Loss: 2.104, Test Acc: 74.72%, Top-5 Acc: 92.56%, Super-Class Acc: 83.98%
# Epoch 61/80, Train Loss: 1.779, Train Acc: 88.06%, Test Loss: 2.102, Test Acc: 74.77%, Top-5 Acc: 92.67%, Super-Class Acc: 83.83%
# Epoch 62/80, Train Loss: 1.768, Train Acc: 88.43%, Test Loss: 2.101, Test Acc: 74.72%, Top-5 Acc: 92.72%, Super-Class Acc: 83.76%
# Epoch 63/80, Train Loss: 1.771, Train Acc: 88.20%, Test Loss: 2.101, Test Acc: 74.76%, Top-5 Acc: 92.68%, Super-Class Acc: 83.97%
# Epoch 64/80, Train Loss: 1.774, Train Acc: 88.21%, Test Loss: 2.098, Test Acc: 74.98%, Top-5 Acc: 92.83%, Super-Class Acc: 84.04%
# Epoch 65/80, Train Loss: 1.770, Train Acc: 88.38%, Test Loss: 2.103, Test Acc: 74.91%, Top-5 Acc: 92.62%, Super-Class Acc: 83.87%
# Epoch 66/80, Train Loss: 1.767, Train Acc: 88.44%, Test Loss: 2.100, Test Acc: 75.00%, Top-5 Acc: 92.69%, Super-Class Acc: 83.91%
# Epoch 67/80, Train Loss: 1.770, Train Acc: 88.43%, Test Loss: 2.099, Test Acc: 75.01%, Top-5 Acc: 92.65%, Super-Class Acc: 83.93%
# Epoch 68/80, Train Loss: 1.766, Train Acc: 88.53%, Test Loss: 2.098, Test Acc: 74.91%, Top-5 Acc: 92.53%, Super-Class Acc: 84.02%
# Epoch 00068: reducing learning rate of group 0 to 1.0000e-05.
# Learning Rate updated: 0.000100 -> 0.000010
# Epoch 69/80, Train Loss: 1.765, Train Acc: 88.56%, Test Loss: 2.102, Test Acc: 74.90%, Top-5 Acc: 92.64%, Super-Class Acc: 83.91%
# Epoch 70/80, Train Loss: 1.764, Train Acc: 88.81%, Test Loss: 2.098, Test Acc: 75.17%, Top-5 Acc: 92.75%, Super-Class Acc: 84.17%
# Epoch 71/80, Train Loss: 1.766, Train Acc: 88.54%, Test Loss: 2.099, Test Acc: 75.05%, Top-5 Acc: 92.61%, Super-Class Acc: 83.98%
# Epoch 72/80, Train Loss: 1.767, Train Acc: 88.57%, Test Loss: 2.096, Test Acc: 75.15%, Top-5 Acc: 92.75%, Super-Class Acc: 84.00%
# Epoch 73/80, Train Loss: 1.766, Train Acc: 88.43%, Test Loss: 2.097, Test Acc: 75.02%, Top-5 Acc: 92.79%, Super-Class Acc: 83.91%
# Epoch 74/80, Train Loss: 1.768, Train Acc: 88.61%, Test Loss: 2.101, Test Acc: 74.93%, Top-5 Acc: 92.72%, Super-Class Acc: 83.82%
# Epoch 75/80, Train Loss: 1.765, Train Acc: 88.58%, Test Loss: 2.099, Test Acc: 74.73%, Top-5 Acc: 92.63%, Super-Class Acc: 83.73%
# Epoch 76/80, Train Loss: 1.758, Train Acc: 88.89%, Test Loss: 2.099, Test Acc: 75.18%, Top-5 Acc: 92.65%, Super-Class Acc: 84.21%
# Epoch 00076: reducing learning rate of group 0 to 1.0000e-06.
# Learning Rate updated: 0.000010 -> 0.000001
# Epoch 77/80, Train Loss: 1.765, Train Acc: 88.58%, Test Loss: 2.098, Test Acc: 74.89%, Top-5 Acc: 92.78%, Super-Class Acc: 83.77%
# Epoch 78/80, Train Loss: 1.762, Train Acc: 88.70%, Test Loss: 2.096, Test Acc: 75.15%, Top-5 Acc: 92.86%, Super-Class Acc: 84.16%
# Epoch 79/80, Train Loss: 1.762, Train Acc: 88.64%, Test Loss: 2.101, Test Acc: 74.96%, Top-5 Acc: 92.64%, Super-Class Acc: 84.17%
# Epoch 80/80, Train Loss: 1.768, Train Acc: 88.40%, Test Loss: 2.100, Test Acc: 75.20%, Top-5 Acc: 92.74%, Super-Class Acc: 84.06%
# Finished Training in 40m 2s
# Final Test Accuracy: 75.20%
# Final Top-5 Accuracy: 92.74%
# Final Super-Class Accuracy: 84.06%

# %%
# !pip install torchviz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting torchviz
#   Downloading torchviz-0.0.2.tar.gz (4.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from torchviz) (2.1.2+cu121)
# Collecting graphviz (from torchviz)
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (3.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (2023.4.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->torchviz) (2.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->torchviz) (2.1.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.11/dist-packages (from sympy->torch->torchviz) (1.3.0)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
# Building wheels for collected packages: torchviz
#   Building wheel for torchviz (setup.py) ... done
#   Created wheel for torchviz: filename=torchviz-0.0.2-py3-none-any.whl size=4131 sha256=d88961b48eeca520fcfc0f9eab2ddcefafea2e7ae81554d05ea4b11dcf4a7575
#   Stored in directory: /home/elema001/.cache/pip/wheels/5a/d0/3f/b7014553eb74f12892b7d9b69c6083044564712d10fde8dfdc
# Successfully built torchviz
# Installing collected packages: graphviz, torchviz
# Successfully installed graphviz-0.20.3 torchviz-0.0.2

# %%
import torch
from torchviz import make_dot

# 创建一个ResNet模型实例
model = ResNet(num_classes=100)

# 创建一个输入张量
x = torch.randn(1, 3, 32, 32)  # 假设输入大小为32x32的RGB图像

# 通过模型进行前向传播
y = model(x)

# 可视化神经网络
dot = make_dot(y, params=dict(model.named_parameters()))
dot.render("/hyx/resnet", format="png")  # 保存到/tmp目录
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[15], line 15
#      13 # 可视化神经网络
#      14 dot = make_dot(y, params=dict(model.named_parameters()))
# ---> 15 dot.render("/hyx/resnet", format="png")  # 保存到/tmp目录
#
# File ~/.local/lib/python3.11/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/graphviz/rendering.py:118, in Render.render(self, filename, directory, view, cleanup, format, renderer, formatter, neato_no_op, quiet, quiet_view, outfile, engine, raise_if_result_exists, overwrite_source)
#     115 if outfile is not None and filename is None:
#     116     filename = self._get_filepath(outfile)
# --> 118 filepath = self.save(filename, directory=directory, skip_existing=None)
#     120 args.append(filepath)
#     122 rendered = self._render(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/graphviz/saving.py:76, in Save.save(self, filename, directory, skip_existing)
#      73 if skip_existing and os.path.exists(filepath):
#      74     return filepath
# ---> 76 self._mkdirs(filepath)
#      78 log.debug('write lines to %r', filepath)
#      79 with open(filepath, 'w', encoding=self.encoding) as fd:
#
# File ~/.local/lib/python3.11/site-packages/graphviz/_tools.py:49, in mkdirs(filename, mode)
#      47     return
#      48 log.debug('os.makedirs(%r)', dirname)
# ---> 49 os.makedirs(dirname, mode=mode, exist_ok=True)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# PermissionError: [Errno 13] Permission denied: '/hyx'
