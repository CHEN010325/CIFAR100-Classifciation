# %%
import torch
import random
import numpy as np
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from main import focal_loss,plot_training_metrics,label_smoothing_loss,train,super_class_mapping,class_to_superclass
import matplotlib.pyplot as plt

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Use of equipment:", device)

# Check the number of GPUs available
num_gpus = torch.cuda.device_count()
print(f"Available GPUs: {num_gpus}")

# Print PyTorch and Torchvision versions
print("PyTorch version:", torch.__version__)
print("torchvision version:", torchvision.__version__)
# Out:
# 使用设备: cuda
# Available GPUs: 1
# PyTorch version: 2.1.2+cu121
# torchvision version: 0.16.2+cu121

# %%
# Setting up random seeds
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Make sure the DataLoader worker uses the same random seed
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# Set up random seeds to ensure reproducibility
set_seed(12)

# %%
# Training set image preprocessing
train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),  # Randomly crop to 32x32 with 4 pixels of padding around the edges
    transforms.RandomHorizontalFlip(),     # Random horizontal flip
    transforms.ToTensor(),                 # Convert to tensor
    transforms.Normalize(
        mean=[0.5071, 0.4867, 0.4408],  # Mean of CIFAR-100
        std=[0.2675, 0.2565, 0.2761]    # Standard deviation of CIFAR-100
    )
])

# Test set image preprocessing (only normalization)
test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to tensor
    transforms.Normalize(
        mean=[0.5071, 0.4867, 0.4408],  # Mean of CIFAR-100
        std=[0.2675, 0.2565, 0.2761]    # Standard deviation of CIFAR-100
    )
])

# %%
root_path = 'data'

# Load the CIFAR-100 training dataset
trainset = torchvision.datasets.CIFAR100(root=root_path, train=True, download=True, transform=train_transform)

# Create a DataLoader for the training dataset, with worker_init_fn to ensure reproducibility
trainloader = torch.utils.data.DataLoader(
    trainset, 
    batch_size=128, 
    shuffle=True, 
    num_workers=2, 
    worker_init_fn=seed_worker  # Ensure reproducibility of the random seed for each worker
)

# Load the CIFAR-100 test dataset
testset = torchvision.datasets.CIFAR100(root=root_path, train=False, download=True, transform=test_transform)

# Create a DataLoader for the test dataset, also with worker_init_fn
testloader = torch.utils.data.DataLoader(
    testset, 
    batch_size=128, 
    shuffle=False, 
    num_workers=2, 
    worker_init_fn=seed_worker  # Ensure reproducibility of the random seed for each worker
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Print the size of the training and test datasets
print(f"Training dataset size: {len(trainset)}")
print(f"Test dataset size: {len(testset)}")
# Out:
# 训练数据集的大小: 50000
# 测试数据集的大小: 10000

# %%
from Wide_ResNet import WideResNet

resnet = WideResNet(depth=28, widen_factor=10, num_classes=100)
resnet.to('cuda')
# Out:
# WideResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): WideBlock(
#       (conv1): Conv2d(16, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential(
#         (0): Conv2d(16, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): WideBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (2): WideBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (3): WideBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): WideBlock(
#       (conv1): Conv2d(160, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential(
#         (0): Conv2d(160, 320, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): WideBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (2): WideBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (3): WideBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): WideBlock(
#       (conv1): Conv2d(320, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential(
#         (0): Conv2d(320, 640, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): WideBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (2): WideBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (3): WideBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#   )
#   (avg_pool): AdaptiveAvgPool2d(output_size=1)
#   (fc): Linear(in_features=640, out_features=100, bias=True)
# )

# %%
def train(model, trainloader, testloader, criterion, optimizer, scheduler, super_class_mapping, class_to_superclass, device='cpu', num_epochs=100):
    """
    Train the model and calculate and print Top-1 accuracy, Top-5 accuracy, and Super-Class accuracy.
    Outputs the best metrics observed during training.
    """
    train_losses = []
    test_losses = []
    train_accuracies = []
    test_accuracies = []

    start_time = time.time()

    best_test_accuracy = 0.0
    best_epoch_metrics = {}

    # 用于保存上一轮学习率
    previous_lr = None

    for epoch in range(num_epochs):
        running_loss = 0.0
        correct_train = 0
        total_train = 0
        correct_super_class_train = 0
        total_super_class_train = 0

        # Training phase
        model.train()
        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

            # Calculate super-class accuracy (optional)
            for idx, label in enumerate(labels):
                superclass = class_to_superclass[label.item()]
                total_super_class_train += 1
                if predicted[idx].item() in super_class_mapping[superclass]:
                    correct_super_class_train += 1

        train_loss = running_loss / len(trainloader)
        train_accuracy = 100 * correct_train / total_train
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)

        # Validation phase
        model.eval()
        running_test_loss = 0.0
        correct_test = 0
        total_test = 0
        correct_top5 = 0
        correct_super_class_test = 0
        total_super_class_test = 0

        with torch.no_grad():
            for data in testloader:
                images, labels = data
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                running_test_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                total_test += labels.size(0)
                correct_test += (predicted == labels).sum().item()

                _, top5_preds = outputs.topk(5, dim=1)
                correct_top5 += (top5_preds == labels.view(-1, 1)).sum().item()

                # Calculate super-class accuracy (optional)
                for idx, label in enumerate(labels):
                    superclass = class_to_superclass[label.item()]
                    total_super_class_test += 1
                    if predicted[idx].item() in super_class_mapping[superclass]:
                        correct_super_class_test += 1

        test_loss = running_test_loss / len(testloader)
        test_accuracy = 100 * correct_test / total_test
        top5_accuracy = 100 * correct_top5 / total_test
        super_class_accuracy_test = 100 * correct_super_class_test / total_super_class_test
        test_losses.append(test_loss)
        test_accuracies.append(test_accuracy)

        # Print metrics
        print(f'Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.3f}, Train Acc: {train_accuracy:.2f}%, Test Loss: {test_loss:.3f}, '
              f'Test Acc: {test_accuracy:.2f}%, Top-5 Acc: {top5_accuracy:.2f}%, Super-Class Acc: {super_class_accuracy_test:.2f}%')

        # Update learning rate
        scheduler.step()
        current_lr = optimizer.param_groups[0]['lr']

        # 如果学习率发生变化，则打印新的学习率
        if previous_lr is None or current_lr != previous_lr:
            print(f'Learning Rate changed to: {current_lr:.6f}')

        # 更新 previous_lr
        previous_lr = current_lr

        # Store best accuracy and corresponding metrics
        if test_accuracy > best_test_accuracy:
            best_test_accuracy = test_accuracy
            best_epoch_metrics = {
                'epoch': epoch + 1,
                'train_loss': train_loss,
                'train_accuracy': train_accuracy,
                'test_loss': test_loss,
                'test_accuracy': test_accuracy,
                'top5_accuracy': top5_accuracy,
                'super_class_accuracy': super_class_accuracy_test
            }

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f'Finished Training in {int(minutes)}m {int(seconds)}s')

    # Output best results
    print('Best Test Results:')
    print(f'Epoch {best_epoch_metrics["epoch"]}, Train Loss: {best_epoch_metrics["train_loss"]:.3f}, Train Acc: {best_epoch_metrics["train_accuracy"]:.2f}%, '
          f'Test Loss: {best_epoch_metrics["test_loss"]:.3f}, Test Acc: {best_epoch_metrics["test_accuracy"]:.2f}%, '
          f'Top-5 Acc: {best_epoch_metrics["top5_accuracy"]:.2f}%, Super-Class Acc: {best_epoch_metrics["super_class_accuracy"]:.2f}%')

    return best_epoch_metrics, train_losses, test_losses, train_accuracies, test_accuracies

# %%
from torch.optim.lr_scheduler import MultiStepLR
import time

optimizer = optim.SGD(
    resnet.parameters(),
    lr=0.1,              # Initial learning rate (typically the maximum learning rate)
    momentum=0.9,
    weight_decay=0.0005,
    nesterov=True
)

# Instantiate the cross-entropy loss function
criterion = nn.CrossEntropyLoss()

scheduler = MultiStepLR(optimizer, milestones=[58, 64, 67, 74], gamma=0.2)

# Call the training function
e, train_losses, test_losses, train_accuracies, test_accuracies = train(
    resnet,
    trainloader,
    testloader,
    criterion,            # Use cross-entropy loss
    optimizer,
    scheduler,            # Add scheduler parameter
    super_class_mapping,  # Add super_class_mapping
    class_to_superclass,  # Add class_to_superclass
    device='cuda',
    num_epochs=80,        
)
# Out:
# Epoch 1/80, Train Loss: 4.422, Train Acc: 5.22%, Test Loss: 3.909, Test Acc: 8.77%, Top-5 Acc: 29.08%, Super-Class Acc: 19.86%
# Learning Rate changed to: 0.100000
# Epoch 2/80, Train Loss: 3.697, Train Acc: 12.22%, Test Loss: 3.518, Test Acc: 15.45%, Top-5 Acc: 41.87%, Super-Class Acc: 27.15%
# Epoch 3/80, Train Loss: 3.282, Train Acc: 19.74%, Test Loss: 3.163, Test Acc: 22.68%, Top-5 Acc: 52.41%, Super-Class Acc: 35.94%
# Epoch 4/80, Train Loss: 2.878, Train Acc: 27.19%, Test Loss: 2.840, Test Acc: 29.87%, Top-5 Acc: 60.39%, Super-Class Acc: 43.96%
# Epoch 5/80, Train Loss: 2.450, Train Acc: 35.75%, Test Loss: 2.435, Test Acc: 37.17%, Top-5 Acc: 69.57%, Super-Class Acc: 51.60%
# Epoch 6/80, Train Loss: 2.122, Train Acc: 42.67%, Test Loss: 2.161, Test Acc: 44.04%, Top-5 Acc: 76.80%, Super-Class Acc: 59.19%
# Epoch 7/80, Train Loss: 1.891, Train Acc: 48.02%, Test Loss: 2.143, Test Acc: 45.33%, Top-5 Acc: 76.07%, Super-Class Acc: 59.33%
# Epoch 8/80, Train Loss: 1.726, Train Acc: 52.14%, Test Loss: 1.975, Test Acc: 48.43%, Top-5 Acc: 79.03%, Super-Class Acc: 62.80%
# Epoch 9/80, Train Loss: 1.612, Train Acc: 54.91%, Test Loss: 1.925, Test Acc: 49.13%, Top-5 Acc: 80.76%, Super-Class Acc: 64.01%
# Epoch 10/80, Train Loss: 1.522, Train Acc: 57.25%, Test Loss: 1.681, Test Acc: 53.87%, Top-5 Acc: 84.28%, Super-Class Acc: 67.78%
# Epoch 11/80, Train Loss: 1.460, Train Acc: 58.55%, Test Loss: 1.710, Test Acc: 54.41%, Top-5 Acc: 83.75%, Super-Class Acc: 67.76%
# Epoch 12/80, Train Loss: 1.404, Train Acc: 60.10%, Test Loss: 1.650, Test Acc: 55.19%, Top-5 Acc: 84.33%, Super-Class Acc: 68.31%
# Epoch 13/80, Train Loss: 1.362, Train Acc: 61.03%, Test Loss: 1.608, Test Acc: 56.30%, Top-5 Acc: 84.70%, Super-Class Acc: 69.61%
# Epoch 14/80, Train Loss: 1.317, Train Acc: 62.54%, Test Loss: 1.764, Test Acc: 54.83%, Top-5 Acc: 83.55%, Super-Class Acc: 67.56%
# Epoch 15/80, Train Loss: 1.289, Train Acc: 63.03%, Test Loss: 1.536, Test Acc: 58.59%, Top-5 Acc: 86.22%, Super-Class Acc: 71.33%
# Epoch 16/80, Train Loss: 1.259, Train Acc: 63.81%, Test Loss: 1.729, Test Acc: 55.45%, Top-5 Acc: 84.76%, Super-Class Acc: 67.02%
# Epoch 17/80, Train Loss: 1.226, Train Acc: 64.62%, Test Loss: 1.573, Test Acc: 58.20%, Top-5 Acc: 86.38%, Super-Class Acc: 70.68%
# Epoch 18/80, Train Loss: 1.215, Train Acc: 64.94%, Test Loss: 1.459, Test Acc: 60.23%, Top-5 Acc: 86.77%, Super-Class Acc: 72.80%
# Epoch 19/80, Train Loss: 1.185, Train Acc: 65.78%, Test Loss: 1.653, Test Acc: 58.20%, Top-5 Acc: 85.27%, Super-Class Acc: 70.91%
# Epoch 20/80, Train Loss: 1.175, Train Acc: 66.04%, Test Loss: 1.551, Test Acc: 59.36%, Top-5 Acc: 86.38%, Super-Class Acc: 71.39%
# Epoch 21/80, Train Loss: 1.155, Train Acc: 66.52%, Test Loss: 1.492, Test Acc: 59.98%, Top-5 Acc: 87.11%, Super-Class Acc: 72.15%
# Epoch 22/80, Train Loss: 1.139, Train Acc: 66.92%, Test Loss: 1.637, Test Acc: 58.17%, Top-5 Acc: 85.39%, Super-Class Acc: 70.80%
# Epoch 23/80, Train Loss: 1.126, Train Acc: 67.41%, Test Loss: 1.441, Test Acc: 61.26%, Top-5 Acc: 87.57%, Super-Class Acc: 73.16%
# Epoch 24/80, Train Loss: 1.110, Train Acc: 67.76%, Test Loss: 1.543, Test Acc: 59.15%, Top-5 Acc: 86.70%, Super-Class Acc: 71.94%
# Epoch 25/80, Train Loss: 1.108, Train Acc: 67.95%, Test Loss: 1.399, Test Acc: 62.00%, Top-5 Acc: 88.16%, Super-Class Acc: 75.44%
# Epoch 26/80, Train Loss: 1.090, Train Acc: 68.27%, Test Loss: 1.635, Test Acc: 57.59%, Top-5 Acc: 84.67%, Super-Class Acc: 70.05%
# Epoch 27/80, Train Loss: 1.081, Train Acc: 68.53%, Test Loss: 1.510, Test Acc: 59.99%, Top-5 Acc: 87.16%, Super-Class Acc: 72.63%
# Epoch 28/80, Train Loss: 1.079, Train Acc: 68.70%, Test Loss: 1.580, Test Acc: 58.37%, Top-5 Acc: 86.13%, Super-Class Acc: 71.05%
# Epoch 29/80, Train Loss: 1.065, Train Acc: 68.85%, Test Loss: 1.519, Test Acc: 59.97%, Top-5 Acc: 86.82%, Super-Class Acc: 72.26%
# Epoch 30/80, Train Loss: 1.061, Train Acc: 68.96%, Test Loss: 1.556, Test Acc: 59.28%, Top-5 Acc: 86.80%, Super-Class Acc: 71.66%
# Epoch 31/80, Train Loss: 1.055, Train Acc: 69.16%, Test Loss: 1.428, Test Acc: 61.78%, Top-5 Acc: 88.47%, Super-Class Acc: 74.70%
# Epoch 32/80, Train Loss: 1.049, Train Acc: 69.36%, Test Loss: 1.464, Test Acc: 62.13%, Top-5 Acc: 88.13%, Super-Class Acc: 74.19%
# Epoch 33/80, Train Loss: 1.038, Train Acc: 69.74%, Test Loss: 1.425, Test Acc: 61.93%, Top-5 Acc: 87.50%, Super-Class Acc: 74.00%
# Epoch 34/80, Train Loss: 1.039, Train Acc: 69.75%, Test Loss: 1.665, Test Acc: 58.51%, Top-5 Acc: 85.78%, Super-Class Acc: 70.83%
# Epoch 35/80, Train Loss: 1.028, Train Acc: 69.97%, Test Loss: 1.474, Test Acc: 61.61%, Top-5 Acc: 87.58%, Super-Class Acc: 73.33%
# Epoch 36/80, Train Loss: 1.036, Train Acc: 70.04%, Test Loss: 1.484, Test Acc: 61.36%, Top-5 Acc: 87.70%, Super-Class Acc: 73.79%
# Epoch 37/80, Train Loss: 1.022, Train Acc: 70.05%, Test Loss: 1.480, Test Acc: 60.61%, Top-5 Acc: 86.73%, Super-Class Acc: 72.20%
# Epoch 38/80, Train Loss: 1.012, Train Acc: 70.32%, Test Loss: 1.442, Test Acc: 61.55%, Top-5 Acc: 87.90%, Super-Class Acc: 73.41%
# Epoch 39/80, Train Loss: 1.016, Train Acc: 70.07%, Test Loss: 1.485, Test Acc: 61.97%, Top-5 Acc: 87.29%, Super-Class Acc: 73.06%
# Epoch 40/80, Train Loss: 1.009, Train Acc: 70.39%, Test Loss: 1.449, Test Acc: 61.44%, Top-5 Acc: 87.50%, Super-Class Acc: 73.36%
# Epoch 41/80, Train Loss: 1.009, Train Acc: 70.13%, Test Loss: 1.507, Test Acc: 60.58%, Top-5 Acc: 87.02%, Super-Class Acc: 71.97%
# Epoch 42/80, Train Loss: 1.010, Train Acc: 70.47%, Test Loss: 1.422, Test Acc: 62.24%, Top-5 Acc: 87.71%, Super-Class Acc: 74.73%
# Epoch 43/80, Train Loss: 0.994, Train Acc: 70.94%, Test Loss: 1.320, Test Acc: 63.67%, Top-5 Acc: 89.68%, Super-Class Acc: 75.72%
# Epoch 44/80, Train Loss: 0.991, Train Acc: 70.89%, Test Loss: 1.770, Test Acc: 57.89%, Top-5 Acc: 84.31%, Super-Class Acc: 69.55%
# Epoch 45/80, Train Loss: 0.991, Train Acc: 70.83%, Test Loss: 1.637, Test Acc: 60.13%, Top-5 Acc: 86.73%, Super-Class Acc: 72.37%
# Epoch 46/80, Train Loss: 0.988, Train Acc: 71.14%, Test Loss: 1.517, Test Acc: 60.55%, Top-5 Acc: 87.15%, Super-Class Acc: 72.30%
# Epoch 47/80, Train Loss: 0.984, Train Acc: 71.20%, Test Loss: 1.327, Test Acc: 63.21%, Top-5 Acc: 88.72%, Super-Class Acc: 74.90%
# Epoch 48/80, Train Loss: 0.986, Train Acc: 71.33%, Test Loss: 1.547, Test Acc: 60.84%, Top-5 Acc: 87.18%, Super-Class Acc: 72.56%
# Epoch 49/80, Train Loss: 0.978, Train Acc: 71.45%, Test Loss: 1.523, Test Acc: 60.98%, Top-5 Acc: 86.85%, Super-Class Acc: 72.10%
# Epoch 50/80, Train Loss: 0.972, Train Acc: 71.52%, Test Loss: 1.381, Test Acc: 63.24%, Top-5 Acc: 88.59%, Super-Class Acc: 75.31%
# Epoch 51/80, Train Loss: 0.974, Train Acc: 71.56%, Test Loss: 1.461, Test Acc: 61.18%, Top-5 Acc: 87.31%, Super-Class Acc: 73.46%
# Epoch 52/80, Train Loss: 0.978, Train Acc: 71.26%, Test Loss: 1.323, Test Acc: 63.79%, Top-5 Acc: 88.70%, Super-Class Acc: 76.30%
# Epoch 53/80, Train Loss: 0.968, Train Acc: 71.62%, Test Loss: 1.477, Test Acc: 61.37%, Top-5 Acc: 87.51%, Super-Class Acc: 73.67%
# Epoch 54/80, Train Loss: 0.969, Train Acc: 71.44%, Test Loss: 1.511, Test Acc: 60.51%, Top-5 Acc: 86.83%, Super-Class Acc: 72.76%
# Epoch 55/80, Train Loss: 0.965, Train Acc: 71.90%, Test Loss: 1.520, Test Acc: 60.14%, Top-5 Acc: 86.92%, Super-Class Acc: 72.28%
# Epoch 56/80, Train Loss: 0.971, Train Acc: 71.32%, Test Loss: 1.497, Test Acc: 61.34%, Top-5 Acc: 86.77%, Super-Class Acc: 73.11%
# Epoch 57/80, Train Loss: 0.958, Train Acc: 71.72%, Test Loss: 1.372, Test Acc: 63.50%, Top-5 Acc: 88.87%, Super-Class Acc: 75.79%
# Epoch 58/80, Train Loss: 0.965, Train Acc: 71.67%, Test Loss: 1.512, Test Acc: 60.28%, Top-5 Acc: 86.48%, Super-Class Acc: 72.33%
# Learning Rate changed to: 0.020000
# Epoch 59/80, Train Loss: 0.554, Train Acc: 83.53%, Test Loss: 0.832, Test Acc: 75.79%, Top-5 Acc: 94.70%, Super-Class Acc: 85.17%
# Epoch 60/80, Train Loss: 0.417, Train Acc: 87.60%, Test Loss: 0.821, Test Acc: 76.67%, Top-5 Acc: 94.70%, Super-Class Acc: 85.52%
# Epoch 61/80, Train Loss: 0.357, Train Acc: 89.67%, Test Loss: 0.832, Test Acc: 76.69%, Top-5 Acc: 94.84%, Super-Class Acc: 85.95%
# Epoch 62/80, Train Loss: 0.318, Train Acc: 90.66%, Test Loss: 0.843, Test Acc: 76.56%, Top-5 Acc: 94.75%, Super-Class Acc: 85.46%
# Epoch 63/80, Train Loss: 0.290, Train Acc: 91.53%, Test Loss: 0.843, Test Acc: 76.68%, Top-5 Acc: 94.77%, Super-Class Acc: 85.77%
# Epoch 64/80, Train Loss: 0.268, Train Acc: 92.16%, Test Loss: 0.887, Test Acc: 76.00%, Top-5 Acc: 94.49%, Super-Class Acc: 85.15%
# Learning Rate changed to: 0.004000
# Epoch 65/80, Train Loss: 0.182, Train Acc: 95.26%, Test Loss: 0.778, Test Acc: 78.77%, Top-5 Acc: 95.29%, Super-Class Acc: 87.22%
# Epoch 66/80, Train Loss: 0.148, Train Acc: 96.44%, Test Loss: 0.777, Test Acc: 78.93%, Top-5 Acc: 95.27%, Super-Class Acc: 87.53%
# Epoch 67/80, Train Loss: 0.135, Train Acc: 96.78%, Test Loss: 0.781, Test Acc: 78.95%, Top-5 Acc: 95.03%, Super-Class Acc: 87.48%
# Learning Rate changed to: 0.000800
# Epoch 68/80, Train Loss: 0.121, Train Acc: 97.31%, Test Loss: 0.774, Test Acc: 79.05%, Top-5 Acc: 95.15%, Super-Class Acc: 87.49%
# Epoch 69/80, Train Loss: 0.117, Train Acc: 97.44%, Test Loss: 0.773, Test Acc: 78.81%, Top-5 Acc: 95.28%, Super-Class Acc: 87.33%
# Epoch 70/80, Train Loss: 0.114, Train Acc: 97.52%, Test Loss: 0.772, Test Acc: 79.05%, Top-5 Acc: 95.14%, Super-Class Acc: 87.54%
# Epoch 71/80, Train Loss: 0.112, Train Acc: 97.50%, Test Loss: 0.772, Test Acc: 79.10%, Top-5 Acc: 95.27%, Super-Class Acc: 87.53%
# Epoch 72/80, Train Loss: 0.111, Train Acc: 97.63%, Test Loss: 0.777, Test Acc: 78.93%, Top-5 Acc: 95.16%, Super-Class Acc: 87.48%
# Epoch 73/80, Train Loss: 0.108, Train Acc: 97.75%, Test Loss: 0.773, Test Acc: 78.97%, Top-5 Acc: 95.33%, Super-Class Acc: 87.46%
# Epoch 74/80, Train Loss: 0.104, Train Acc: 97.87%, Test Loss: 0.775, Test Acc: 78.91%, Top-5 Acc: 95.19%, Super-Class Acc: 87.54%
# Learning Rate changed to: 0.000160
# Epoch 75/80, Train Loss: 0.103, Train Acc: 97.91%, Test Loss: 0.774, Test Acc: 79.14%, Top-5 Acc: 95.27%, Super-Class Acc: 87.74%
# Epoch 76/80, Train Loss: 0.104, Train Acc: 97.85%, Test Loss: 0.776, Test Acc: 79.07%, Top-5 Acc: 95.09%, Super-Class Acc: 87.63%
# Epoch 77/80, Train Loss: 0.101, Train Acc: 97.97%, Test Loss: 0.782, Test Acc: 78.94%, Top-5 Acc: 95.13%, Super-Class Acc: 87.49%
# Epoch 78/80, Train Loss: 0.101, Train Acc: 97.97%, Test Loss: 0.777, Test Acc: 79.00%, Top-5 Acc: 95.13%, Super-Class Acc: 87.56%
# Epoch 79/80, Train Loss: 0.102, Train Acc: 97.83%, Test Loss: 0.777, Test Acc: 78.97%, Top-5 Acc: 95.17%, Super-Class Acc: 87.54%
# Epoch 80/80, Train Loss: 0.102, Train Acc: 97.83%, Test Loss: 0.777, Test Acc: 79.09%, Top-5 Acc: 95.16%, Super-Class Acc: 87.64%
# Finished Training in 626m 9s
# Best Test Results:
# Epoch 75, Train Loss: 0.103, Train Acc: 97.91%, Test Loss: 0.774, Test Acc: 79.14%, Top-5 Acc: 95.27%, Super-Class Acc: 87.74%

# %%
plot_training_metrics(train_losses, test_losses, train_accuracies, test_accuracies)
