# %%
import torch
import random
import numpy as np
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from main import focal_loss,plot_training_metrics,label_smoothing_loss,train,super_class_mapping,class_to_superclass
import matplotlib.pyplot as plt

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device in use:", device)

# Check the number of available GPUs
num_gpus = torch.cuda.device_count()
print(f"Available GPUs: {num_gpus}")

# Print PyTorch and torchvision versions
print("PyTorch version:", torch.__version__)
print("torchvision version:", torchvision.__version__)
# Out:
# 使用设备: cuda
# Available GPUs: 1
# PyTorch version: 2.1.2+cu121
# torchvision version: 0.16.2+cu121

# %%
# Set random seed
def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

# Ensure DataLoader workers use the same random seed
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# Set random seed to ensure reproducibility
set_seed(4)

# %%
# Image preprocessing for the training set
train_transform = transforms.Compose([
    transforms.RandomCrop(32, padding=4),  # Randomly crop to 32x32 with 4 pixels of padding
    transforms.RandomHorizontalFlip(),     # Random horizontal flip
    transforms.ToTensor(),                 # Convert to tensor
    transforms.Normalize(
        mean=[0.5071, 0.4867, 0.4408],  # Mean of CIFAR-100
        std=[0.2675, 0.2565, 0.2761]    # Standard deviation of CIFAR-100
    )
])

# Image preprocessing for the test set (normalization only)
test_transform = transforms.Compose([
    transforms.ToTensor(),  # Convert to tensor
    transforms.Normalize(
        mean=[0.5071, 0.4867, 0.4408],  # Mean of CIFAR-100
        std=[0.2675, 0.2565, 0.2761]    # Standard deviation of CIFAR-100
    )
])

# %%
root_path = 'data'

# Load CIFAR-100 training dataset
trainset = torchvision.datasets.CIFAR100(root=root_path, train=True, download=True, transform=train_transform)

# Create DataLoader for the training dataset, adding the worker_init_fn parameter to ensure reproducibility
trainloader = torch.utils.data.DataLoader(
    trainset, 
    batch_size=128, 
    shuffle=True, 
    num_workers=2, 
    worker_init_fn=seed_worker  # Ensure each worker's random seed is reproducible
)

# Load CIFAR-100 test dataset
testset = torchvision.datasets.CIFAR100(root=root_path, train=False, download=True, transform=test_transform)

# Create DataLoader for the test dataset, also adding the worker_init_fn parameter
testloader = torch.utils.data.DataLoader(
    testset, 
    batch_size=128, 
    shuffle=False, 
    num_workers=2, 
    worker_init_fn=seed_worker  # Ensure each worker's random seed is reproducible
)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# Print the size of the training and test datasets
print(f"Training dataset size: {len(trainset)}")
print(f"Test dataset size: {len(testset)}")
# Out:
# 训练数据集的大小: 50000
# 测试数据集的大小: 10000

# %%
from Wide_ResNet import WideResNet

resnet = WideResNet(depth=28, widen_factor=10, num_classes=100)
resnet.to('cuda')
# Out:
# WideResNet(
#   (conv1): Conv2d(3, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): WideBlock(
#       (conv1): Conv2d(16, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential(
#         (0): Conv2d(16, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): WideBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (2): WideBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (3): WideBlock(
#       (conv1): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(160, 160, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): WideBlock(
#       (conv1): Conv2d(160, 320, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential(
#         (0): Conv2d(160, 320, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): WideBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (2): WideBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (3): WideBlock(
#       (conv1): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(320, 320, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): WideBlock(
#       (conv1): Conv2d(320, 640, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential(
#         (0): Conv2d(320, 640, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): WideBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (2): WideBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#     (3): WideBlock(
#       (conv1): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout1): Dropout(p=0.3, inplace=False)
#       (conv2): Conv2d(640, 640, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(640, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (dropout2): Dropout(p=0.3, inplace=False)
#       (shortcut): Sequential()
#     )
#   )
#   (avg_pool): AdaptiveAvgPool2d(output_size=1)
#   (fc): Linear(in_features=640, out_features=100, bias=True)
# )

# %%
def train(model, trainloader, testloader, criterion, optimizer, scheduler, super_class_mapping, class_to_superclass, device='cpu', num_epochs=100):
    """
    Train the model and calculate and print Top-1 accuracy, Top-5 accuracy, and Super-Class accuracy.
    Outputs the best metrics observed during training.
    """
    train_losses = []
    test_losses = []
    train_accuracies = []
    test_accuracies = []

    start_time = time.time()

    best_test_accuracy = 0.0
    best_epoch_metrics = {}

    # 用于保存上一轮学习率
    previous_lr = None

    for epoch in range(num_epochs):
        running_loss = 0.0
        correct_train = 0
        total_train = 0
        correct_super_class_train = 0
        total_super_class_train = 0

        # Training phase
        model.train()
        for i, data in enumerate(trainloader, 0):
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()

            # Calculate super-class accuracy (optional)
            for idx, label in enumerate(labels):
                superclass = class_to_superclass[label.item()]
                total_super_class_train += 1
                if predicted[idx].item() in super_class_mapping[superclass]:
                    correct_super_class_train += 1

        train_loss = running_loss / len(trainloader)
        train_accuracy = 100 * correct_train / total_train
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)

        # Validation phase
        model.eval()
        running_test_loss = 0.0
        correct_test = 0
        total_test = 0
        correct_top5 = 0
        correct_super_class_test = 0
        total_super_class_test = 0

        with torch.no_grad():
            for data in testloader:
                images, labels = data
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                running_test_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                total_test += labels.size(0)
                correct_test += (predicted == labels).sum().item()

                _, top5_preds = outputs.topk(5, dim=1)
                correct_top5 += (top5_preds == labels.view(-1, 1)).sum().item()

                # Calculate super-class accuracy (optional)
                for idx, label in enumerate(labels):
                    superclass = class_to_superclass[label.item()]
                    total_super_class_test += 1
                    if predicted[idx].item() in super_class_mapping[superclass]:
                        correct_super_class_test += 1

        test_loss = running_test_loss / len(testloader)
        test_accuracy = 100 * correct_test / total_test
        top5_accuracy = 100 * correct_top5 / total_test
        super_class_accuracy_test = 100 * correct_super_class_test / total_super_class_test
        test_losses.append(test_loss)
        test_accuracies.append(test_accuracy)

        # Print metrics
        print(f'Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_loss:.3f}, Train Acc: {train_accuracy:.2f}%, Test Loss: {test_loss:.3f}, '
              f'Test Acc: {test_accuracy:.2f}%, Top-5 Acc: {top5_accuracy:.2f}%, Super-Class Acc: {super_class_accuracy_test:.2f}%')

        # Update learning rate
        scheduler.step()
        current_lr = optimizer.param_groups[0]['lr']

        # 如果学习率发生变化，则打印新的学习率
        if previous_lr is None or current_lr != previous_lr:
            print(f'Learning Rate changed to: {current_lr:.6f}')

        # 更新 previous_lr
        previous_lr = current_lr

        # Store best accuracy and corresponding metrics
        if test_accuracy > best_test_accuracy:
            best_test_accuracy = test_accuracy
            best_epoch_metrics = {
                'epoch': epoch + 1,
                'train_loss': train_loss,
                'train_accuracy': train_accuracy,
                'test_loss': test_loss,
                'test_accuracy': test_accuracy,
                'top5_accuracy': top5_accuracy,
                'super_class_accuracy': super_class_accuracy_test
            }

    total_time = time.time() - start_time
    minutes, seconds = divmod(total_time, 60)
    print(f'Finished Training in {int(minutes)}m {int(seconds)}s')

    # Output best results
    print('Best Test Results:')
    print(f'Epoch {best_epoch_metrics["epoch"]}, Train Loss: {best_epoch_metrics["train_loss"]:.3f}, Train Acc: {best_epoch_metrics["train_accuracy"]:.2f}%, '
          f'Test Loss: {best_epoch_metrics["test_loss"]:.3f}, Test Acc: {best_epoch_metrics["test_accuracy"]:.2f}%, '
          f'Top-5 Acc: {best_epoch_metrics["top5_accuracy"]:.2f}%, Super-Class Acc: {best_epoch_metrics["super_class_accuracy"]:.2f}%')

    return best_epoch_metrics, train_losses, test_losses, train_accuracies, test_accuracies

# %%
from torch.optim.lr_scheduler import MultiStepLR
import time

# label_smoothing_loss with smoothing=0.175, momentum=0.95, batch_size=32, nesterov=True, and ReduceLROnPlateau scheduler
optimizer = optim.SGD(
    resnet.parameters(),
    lr=0.1,              # Initial learning rate (typically the maximum learning rate)
    momentum=0.9,
    weight_decay=0.0005,
    nesterov=True
)

# Instantiate the cross-entropy loss function
criterion = nn.CrossEntropyLoss()

scheduler = MultiStepLR(optimizer, milestones=[58, 64, 67, 74], gamma=0.2)

# Call the training function
e, train_losses, test_losses, train_accuracies, test_accuracies = train(
    resnet,
    trainloader,
    testloader,
    criterion,           # Use cross-entropy loss
    optimizer,
    scheduler,           # Add scheduler parameter
    super_class_mapping, # Add super_class_mapping
    class_to_superclass, # Add class_to_superclass
    device='cuda',
    num_epochs=80,
)
# Out:
# Epoch 1/80, Train Loss: 4.886, Train Acc: 1.82%, Test Loss: 4.399, Test Acc: 2.54%, Top-5 Acc: 11.68%, Super-Class Acc: 9.80%
# Learning Rate changed to: 0.100000
# Epoch 2/80, Train Loss: 4.153, Train Acc: 5.19%, Test Loss: 3.911, Test Acc: 8.51%, Top-5 Acc: 27.78%, Super-Class Acc: 18.35%
# Epoch 3/80, Train Loss: 3.759, Train Acc: 11.12%, Test Loss: 3.648, Test Acc: 13.62%, Top-5 Acc: 38.36%, Super-Class Acc: 25.58%
# Epoch 4/80, Train Loss: 3.400, Train Acc: 17.26%, Test Loss: 3.273, Test Acc: 20.22%, Top-5 Acc: 49.01%, Super-Class Acc: 33.91%
# Epoch 5/80, Train Loss: 3.022, Train Acc: 24.43%, Test Loss: 2.904, Test Acc: 26.81%, Top-5 Acc: 57.74%, Super-Class Acc: 41.55%
# Epoch 6/80, Train Loss: 2.657, Train Acc: 31.66%, Test Loss: 2.645, Test Acc: 32.49%, Top-5 Acc: 65.47%, Super-Class Acc: 47.78%
# Epoch 7/80, Train Loss: 2.337, Train Acc: 38.13%, Test Loss: 2.310, Test Acc: 39.90%, Top-5 Acc: 73.28%, Super-Class Acc: 54.93%
# Epoch 8/80, Train Loss: 2.087, Train Acc: 43.64%, Test Loss: 2.157, Test Acc: 43.32%, Top-5 Acc: 75.91%, Super-Class Acc: 58.14%
# Epoch 9/80, Train Loss: 1.896, Train Acc: 47.83%, Test Loss: 2.140, Test Acc: 44.18%, Top-5 Acc: 76.37%, Super-Class Acc: 58.19%
# Epoch 10/80, Train Loss: 1.759, Train Acc: 51.33%, Test Loss: 1.810, Test Acc: 51.25%, Top-5 Acc: 81.21%, Super-Class Acc: 64.70%
# Epoch 11/80, Train Loss: 1.652, Train Acc: 53.61%, Test Loss: 1.834, Test Acc: 50.93%, Top-5 Acc: 81.80%, Super-Class Acc: 65.20%
# Epoch 12/80, Train Loss: 1.573, Train Acc: 56.25%, Test Loss: 1.801, Test Acc: 51.86%, Top-5 Acc: 81.77%, Super-Class Acc: 65.32%
# Epoch 13/80, Train Loss: 1.497, Train Acc: 57.80%, Test Loss: 1.777, Test Acc: 52.33%, Top-5 Acc: 82.73%, Super-Class Acc: 66.02%
# Epoch 14/80, Train Loss: 1.448, Train Acc: 59.09%, Test Loss: 1.879, Test Acc: 51.31%, Top-5 Acc: 81.35%, Super-Class Acc: 64.97%
# Epoch 15/80, Train Loss: 1.396, Train Acc: 60.28%, Test Loss: 1.877, Test Acc: 52.30%, Top-5 Acc: 81.98%, Super-Class Acc: 65.04%
# Epoch 16/80, Train Loss: 1.355, Train Acc: 61.50%, Test Loss: 1.700, Test Acc: 54.50%, Top-5 Acc: 83.68%, Super-Class Acc: 68.09%
# Epoch 17/80, Train Loss: 1.320, Train Acc: 62.22%, Test Loss: 1.532, Test Acc: 58.95%, Top-5 Acc: 85.76%, Super-Class Acc: 71.69%
# Epoch 18/80, Train Loss: 1.301, Train Acc: 62.83%, Test Loss: 1.679, Test Acc: 56.97%, Top-5 Acc: 84.15%, Super-Class Acc: 69.07%
# Epoch 19/80, Train Loss: 1.271, Train Acc: 63.61%, Test Loss: 1.624, Test Acc: 57.66%, Top-5 Acc: 86.04%, Super-Class Acc: 69.91%
# Epoch 20/80, Train Loss: 1.238, Train Acc: 64.59%, Test Loss: 1.585, Test Acc: 58.36%, Top-5 Acc: 85.77%, Super-Class Acc: 70.79%
# Epoch 21/80, Train Loss: 1.227, Train Acc: 64.73%, Test Loss: 1.956, Test Acc: 52.32%, Top-5 Acc: 81.44%, Super-Class Acc: 65.24%
# Epoch 22/80, Train Loss: 1.203, Train Acc: 65.35%, Test Loss: 1.487, Test Acc: 59.62%, Top-5 Acc: 86.75%, Super-Class Acc: 72.37%
# Epoch 23/80, Train Loss: 1.181, Train Acc: 65.87%, Test Loss: 1.545, Test Acc: 58.67%, Top-5 Acc: 86.61%, Super-Class Acc: 71.28%
# Epoch 24/80, Train Loss: 1.170, Train Acc: 66.29%, Test Loss: 1.589, Test Acc: 57.85%, Top-5 Acc: 85.41%, Super-Class Acc: 70.36%
# Epoch 25/80, Train Loss: 1.155, Train Acc: 66.51%, Test Loss: 1.608, Test Acc: 57.65%, Top-5 Acc: 85.53%, Super-Class Acc: 70.87%
# Epoch 26/80, Train Loss: 1.138, Train Acc: 67.22%, Test Loss: 1.523, Test Acc: 58.80%, Top-5 Acc: 86.52%, Super-Class Acc: 71.63%
# Epoch 27/80, Train Loss: 1.132, Train Acc: 67.31%, Test Loss: 1.431, Test Acc: 60.77%, Top-5 Acc: 87.94%, Super-Class Acc: 72.93%
# Epoch 28/80, Train Loss: 1.120, Train Acc: 67.59%, Test Loss: 1.486, Test Acc: 59.93%, Top-5 Acc: 87.81%, Super-Class Acc: 73.06%
# Epoch 29/80, Train Loss: 1.101, Train Acc: 67.89%, Test Loss: 1.495, Test Acc: 60.62%, Top-5 Acc: 86.97%, Super-Class Acc: 72.17%
# Epoch 30/80, Train Loss: 1.103, Train Acc: 67.89%, Test Loss: 1.491, Test Acc: 61.04%, Top-5 Acc: 87.53%, Super-Class Acc: 73.61%
# Epoch 31/80, Train Loss: 1.093, Train Acc: 68.11%, Test Loss: 1.619, Test Acc: 59.05%, Top-5 Acc: 85.65%, Super-Class Acc: 71.22%
# Epoch 32/80, Train Loss: 1.077, Train Acc: 68.46%, Test Loss: 1.518, Test Acc: 59.05%, Top-5 Acc: 86.99%, Super-Class Acc: 71.50%
# Epoch 33/80, Train Loss: 1.076, Train Acc: 68.91%, Test Loss: 1.578, Test Acc: 58.87%, Top-5 Acc: 86.19%, Super-Class Acc: 71.33%
# Epoch 34/80, Train Loss: 1.077, Train Acc: 68.55%, Test Loss: 1.807, Test Acc: 54.96%, Top-5 Acc: 83.64%, Super-Class Acc: 66.21%
# Epoch 35/80, Train Loss: 1.057, Train Acc: 69.25%, Test Loss: 1.849, Test Acc: 56.33%, Top-5 Acc: 84.07%, Super-Class Acc: 68.16%
# Epoch 36/80, Train Loss: 1.066, Train Acc: 68.91%, Test Loss: 1.578, Test Acc: 59.40%, Top-5 Acc: 86.11%, Super-Class Acc: 70.89%
# Epoch 37/80, Train Loss: 1.052, Train Acc: 69.04%, Test Loss: 1.480, Test Acc: 62.33%, Top-5 Acc: 88.22%, Super-Class Acc: 74.26%
# Epoch 38/80, Train Loss: 1.042, Train Acc: 69.55%, Test Loss: 1.423, Test Acc: 62.00%, Top-5 Acc: 87.98%, Super-Class Acc: 73.36%
# Epoch 39/80, Train Loss: 1.039, Train Acc: 69.76%, Test Loss: 1.552, Test Acc: 58.89%, Top-5 Acc: 86.64%, Super-Class Acc: 70.69%
# Epoch 40/80, Train Loss: 1.042, Train Acc: 69.64%, Test Loss: 1.493, Test Acc: 60.90%, Top-5 Acc: 86.71%, Super-Class Acc: 72.12%
# Epoch 41/80, Train Loss: 1.039, Train Acc: 69.62%, Test Loss: 1.516, Test Acc: 60.58%, Top-5 Acc: 86.99%, Super-Class Acc: 72.21%
# Epoch 42/80, Train Loss: 1.028, Train Acc: 69.84%, Test Loss: 1.500, Test Acc: 60.58%, Top-5 Acc: 87.58%, Super-Class Acc: 72.16%
# Epoch 43/80, Train Loss: 1.019, Train Acc: 70.27%, Test Loss: 1.420, Test Acc: 62.67%, Top-5 Acc: 88.07%, Super-Class Acc: 74.43%
# Epoch 44/80, Train Loss: 1.019, Train Acc: 70.40%, Test Loss: 1.518, Test Acc: 61.38%, Top-5 Acc: 87.87%, Super-Class Acc: 73.59%
# Epoch 45/80, Train Loss: 1.014, Train Acc: 70.48%, Test Loss: 1.486, Test Acc: 60.63%, Top-5 Acc: 87.28%, Super-Class Acc: 72.36%
# Epoch 46/80, Train Loss: 1.020, Train Acc: 70.17%, Test Loss: 1.359, Test Acc: 62.71%, Top-5 Acc: 88.68%, Super-Class Acc: 74.50%
# Epoch 47/80, Train Loss: 1.014, Train Acc: 70.34%, Test Loss: 1.609, Test Acc: 59.15%, Top-5 Acc: 85.63%, Super-Class Acc: 70.56%
# Epoch 48/80, Train Loss: 1.003, Train Acc: 70.67%, Test Loss: 1.417, Test Acc: 62.62%, Top-5 Acc: 87.75%, Super-Class Acc: 73.99%
# Epoch 49/80, Train Loss: 1.007, Train Acc: 70.68%, Test Loss: 1.499, Test Acc: 61.17%, Top-5 Acc: 87.52%, Super-Class Acc: 73.84%
# Epoch 50/80, Train Loss: 0.998, Train Acc: 70.82%, Test Loss: 1.475, Test Acc: 61.01%, Top-5 Acc: 87.61%, Super-Class Acc: 72.52%
# Epoch 51/80, Train Loss: 0.996, Train Acc: 70.83%, Test Loss: 1.451, Test Acc: 61.93%, Top-5 Acc: 87.65%, Super-Class Acc: 73.43%
# Epoch 52/80, Train Loss: 0.993, Train Acc: 70.83%, Test Loss: 1.498, Test Acc: 60.89%, Top-5 Acc: 87.41%, Super-Class Acc: 72.91%
# Epoch 53/80, Train Loss: 0.991, Train Acc: 70.83%, Test Loss: 1.534, Test Acc: 60.31%, Top-5 Acc: 86.10%, Super-Class Acc: 71.76%
# Epoch 54/80, Train Loss: 0.991, Train Acc: 71.12%, Test Loss: 1.541, Test Acc: 59.72%, Top-5 Acc: 87.61%, Super-Class Acc: 73.01%
# Epoch 55/80, Train Loss: 0.994, Train Acc: 70.96%, Test Loss: 1.585, Test Acc: 58.99%, Top-5 Acc: 86.71%, Super-Class Acc: 71.48%
# Epoch 56/80, Train Loss: 0.987, Train Acc: 71.12%, Test Loss: 1.432, Test Acc: 63.11%, Top-5 Acc: 88.77%, Super-Class Acc: 74.22%
# Epoch 57/80, Train Loss: 0.982, Train Acc: 71.11%, Test Loss: 1.372, Test Acc: 63.21%, Top-5 Acc: 88.36%, Super-Class Acc: 74.98%
# Epoch 58/80, Train Loss: 0.978, Train Acc: 71.16%, Test Loss: 1.353, Test Acc: 63.88%, Top-5 Acc: 88.88%, Super-Class Acc: 75.55%
# Learning Rate changed to: 0.020000
# Epoch 59/80, Train Loss: 0.570, Train Acc: 83.42%, Test Loss: 0.842, Test Acc: 75.69%, Top-5 Acc: 94.64%, Super-Class Acc: 85.26%
# Epoch 60/80, Train Loss: 0.436, Train Acc: 87.22%, Test Loss: 0.851, Test Acc: 76.13%, Top-5 Acc: 94.46%, Super-Class Acc: 84.88%
# Epoch 61/80, Train Loss: 0.381, Train Acc: 88.74%, Test Loss: 0.840, Test Acc: 76.49%, Top-5 Acc: 94.71%, Super-Class Acc: 85.45%
# Epoch 62/80, Train Loss: 0.342, Train Acc: 90.01%, Test Loss: 0.865, Test Acc: 76.23%, Top-5 Acc: 94.61%, Super-Class Acc: 85.22%
# Epoch 63/80, Train Loss: 0.310, Train Acc: 90.94%, Test Loss: 0.886, Test Acc: 76.07%, Top-5 Acc: 94.28%, Super-Class Acc: 85.07%
# Epoch 64/80, Train Loss: 0.281, Train Acc: 92.00%, Test Loss: 0.900, Test Acc: 76.05%, Top-5 Acc: 94.63%, Super-Class Acc: 84.94%
# Learning Rate changed to: 0.004000
# Epoch 65/80, Train Loss: 0.191, Train Acc: 94.94%, Test Loss: 0.793, Test Acc: 78.39%, Top-5 Acc: 95.37%, Super-Class Acc: 86.81%
# Epoch 66/80, Train Loss: 0.162, Train Acc: 95.88%, Test Loss: 0.795, Test Acc: 78.34%, Top-5 Acc: 95.37%, Super-Class Acc: 86.73%
# Epoch 67/80, Train Loss: 0.147, Train Acc: 96.49%, Test Loss: 0.783, Test Acc: 79.05%, Top-5 Acc: 95.33%, Super-Class Acc: 87.21%
# Learning Rate changed to: 0.000800
# Epoch 68/80, Train Loss: 0.130, Train Acc: 97.02%, Test Loss: 0.787, Test Acc: 78.89%, Top-5 Acc: 95.43%, Super-Class Acc: 87.29%
# Epoch 69/80, Train Loss: 0.125, Train Acc: 97.24%, Test Loss: 0.784, Test Acc: 78.89%, Top-5 Acc: 95.52%, Super-Class Acc: 87.26%
# Epoch 70/80, Train Loss: 0.125, Train Acc: 97.14%, Test Loss: 0.784, Test Acc: 78.81%, Top-5 Acc: 95.53%, Super-Class Acc: 87.16%
# Epoch 71/80, Train Loss: 0.122, Train Acc: 97.43%, Test Loss: 0.787, Test Acc: 78.88%, Top-5 Acc: 95.47%, Super-Class Acc: 87.17%
# Epoch 72/80, Train Loss: 0.119, Train Acc: 97.38%, Test Loss: 0.790, Test Acc: 78.85%, Top-5 Acc: 95.39%, Super-Class Acc: 87.31%
# Epoch 73/80, Train Loss: 0.118, Train Acc: 97.36%, Test Loss: 0.795, Test Acc: 78.62%, Top-5 Acc: 95.26%, Super-Class Acc: 86.95%
# Epoch 74/80, Train Loss: 0.116, Train Acc: 97.47%, Test Loss: 0.793, Test Acc: 78.73%, Top-5 Acc: 95.30%, Super-Class Acc: 87.00%
# Learning Rate changed to: 0.000160
# Epoch 75/80, Train Loss: 0.111, Train Acc: 97.68%, Test Loss: 0.790, Test Acc: 78.78%, Top-5 Acc: 95.33%, Super-Class Acc: 87.09%
# Epoch 76/80, Train Loss: 0.112, Train Acc: 97.64%, Test Loss: 0.790, Test Acc: 78.87%, Top-5 Acc: 95.42%, Super-Class Acc: 87.18%
# Epoch 77/80, Train Loss: 0.109, Train Acc: 97.71%, Test Loss: 0.791, Test Acc: 78.77%, Top-5 Acc: 95.42%, Super-Class Acc: 87.07%
# Epoch 78/80, Train Loss: 0.114, Train Acc: 97.52%, Test Loss: 0.791, Test Acc: 78.73%, Top-5 Acc: 95.42%, Super-Class Acc: 87.11%
# Epoch 79/80, Train Loss: 0.111, Train Acc: 97.70%, Test Loss: 0.795, Test Acc: 78.79%, Top-5 Acc: 95.33%, Super-Class Acc: 86.99%
# Epoch 80/80, Train Loss: 0.110, Train Acc: 97.59%, Test Loss: 0.792, Test Acc: 78.66%, Top-5 Acc: 95.32%, Super-Class Acc: 86.99%
# Finished Training in 687m 51s
# Best Test Results:
# Epoch 67, Train Loss: 0.147, Train Acc: 96.49%, Test Loss: 0.783, Test Acc: 79.05%, Top-5 Acc: 95.33%, Super-Class Acc: 87.21%

# %%
plot_training_metrics(train_losses, test_losses, train_accuracies, test_accuracies)
